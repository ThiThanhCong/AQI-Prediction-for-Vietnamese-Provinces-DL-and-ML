# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Conv1D, Add, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Load the data
df = pd.read_csv(r'C:\Users\ASUS\Desktop\ptdl\QuangNinh.csv')
print(df.columns)

# Preprocess the data
df['date'] = pd.to_datetime(df['date'])  # Chuyển đổi cột date thành định dạng thời gian
df.set_index('date', inplace=True)  # Đặt cột date làm index
df = df.loc['2019-03-01':'2024-03-01']  # Chọn phạm vi thời gian cụ thể

# Check for null values and drop them
null_count = df.isnull().sum()
print(null_count)
df = df.dropna()

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['AQI']])

# Prepare data function
def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

timesteps = 10  # Độ dài của cửa sổ trượt
X, y = prepare_data(scaled_data, timesteps)



# Build the model
input_layer = Input(shape=(timesteps, 1))
x = LSTM(64, return_sequences=True)(input_layer)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = Conv1D(64, kernel_size=2, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=1, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(1, kernel_size=3, padding='same')(x)
x = Add()([x, input_layer])
output_layer = Activation('tanh')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Index(['Unnamed: 0', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'AQI'], dtype='object')
# Unnamed: 0    0
# pm25          0
# pm10          0
# o3            0
# no2           0
# so2           0
# co            0
# AQI           0
# dtype: int64
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 10, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ (None, 10, 64)            │          16,896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 10, 64)            │          12,352 │ lstm[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 10, 64)            │           8,256 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 10, 64)            │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 10, 64)            │           4,160 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 10, 64)            │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 10, 64)            │          12,352 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 10, 64)            │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 10, 1)             │             193 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 10, 1)             │               0 │ conv1d_4[0][0],            │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 10, 1)             │               0 │ add[0][0]                  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 54,977 (214.75 KB)
#  Trainable params: 54,593 (213.25 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Assuming df, model, scaler, X_train, y_train, X_test, y_test, and timesteps are already defined
def custom_round(number):
    if number >= 0:
        return int(number + 0.5)  # Làm tròn lên
    else:
        return int(number - 0.5)  # Làm tròn xuống
train_sizes = [0.7, 0.8, 0.9]
for train_size_ratio in train_sizes:
    # Split data into training and testing sets
    train_size = int(len(X) * train_size_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    # Reshape data to match model input
    X_train = np.reshape(X_train, (X_train.shape[0], timesteps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], timesteps, 1))
    
    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Inverse transform the predictions and true values
    y_pred_inverse = scaler.inverse_transform(y_pred[:, -1, 0].reshape(-1, 1))
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_train_inverse = scaler.inverse_transform(y_train.reshape(-1, 1))
    
    # Calculate error metrics
    rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    
    # Extend the index by 30 days
    last_index = df.index[-1]
    
    if isinstance(df.index, pd.DatetimeIndex):
        new_index = pd.date_range(start=last_index, periods=31, freq='D')[1:]
    elif isinstance(df.index, pd.RangeIndex):
        new_index = pd.RangeIndex(start=last_index + 1, stop=last_index + 31, step=1)
    
    
    # Create an array of 30 consecutive integers starting from the last index
    if isinstance(df.index, pd.DatetimeIndex):
        x_next_30_days = np.array(range(1, 31)).reshape(-1, 1)
    elif isinstance(df.index, pd.RangeIndex):
        x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
    
    # Predict the AQI for the next 30 days
    y_next_30_days = model.predict(x_next_30_days)
    y_next_30_days_flat = scaler.inverse_transform(y_next_30_days[:, -1, 0].reshape(-1, 1)).flatten()
    # Plot the results
    plt.figure(figsize=(12, 6))
    plt.plot(df.index[:len(y_train_inverse)], y_train_inverse, label='Train')
    plt.plot(df.index[-len(y_test_inverse):], y_test_inverse, label='Actual AQI')
    plt.plot(df.index[-len(y_test_inverse):], y_pred_inverse, label='Predicted AQI')
    plt.plot(new_index, y_next_30_days_flat, label='Predicted Next 30 Days')
    plt.xlabel('Date')
    plt.ylabel('AQI')
    plt.title(f'Actual vs Predicted AQI split {custom_round(train_size_ratio * 10)}:{custom_round((1-train_size_ratio)*10)}')
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.2248 - mae: 0.3777 - val_loss: 0.0074 - val_mae: 0.0362
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0193 - mae: 0.1060 - val_loss: 0.0105 - val_mae: 0.0628
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0603 - val_loss: 0.0142 - val_mae: 0.0815
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0612 - val_loss: 0.0183 - val_mae: 0.0975
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - mae: 0.0519 - val_loss: 0.0228 - val_mae: 0.1118
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0389 - val_loss: 0.0270 - val_mae: 0.1240
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0424 - val_loss: 0.0298 - val_mae: 0.1291
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0379 - val_loss: 0.0333 - val_mae: 0.1374
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0448 - val_loss: 0.0332 - val_mae: 0.1323
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0406 - val_loss: 0.0361 - val_mae: 0.1388
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mae: 0.0355 - val_loss: 0.0374 - val_mae: 0.1398
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0394 - val_loss: 0.0365 - val_mae: 0.1332
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0364 - val_loss: 0.0397 - val_mae: 0.1441
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0388 - val_loss: 0.0360 - val_mae: 0.1291
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0424 - val_loss: 0.0365 - val_mae: 0.1307
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mae: 0.0352 - val_loss: 0.0337 - val_mae: 0.1206
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mae: 0.0313 - val_loss: 0.0309 - val_mae: 0.1109
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 0.0304 - val_mae: 0.1115
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0316 - val_loss: 0.0273 - val_mae: 0.1065
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0307 - val_loss: 0.0272 - val_mae: 0.1071
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0312 - val_loss: 0.0264 - val_mae: 0.1124
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0253 - val_mae: 0.1135
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0248 - val_mae: 0.1165
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0307 - val_loss: 0.0252 - val_mae: 0.1231
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0228 - val_mae: 0.1151
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0267 - val_mae: 0.1374
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mae: 0.0358 - val_loss: 0.0221 - val_mae: 0.1191
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mae: 0.0315 - val_loss: 0.0212 - val_mae: 0.1175
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0296 - val_loss: 0.0208 - val_mae: 0.1165
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0188 - val_mae: 0.1052
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0304 - val_loss: 0.0175 - val_mae: 0.1034
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0160 - val_mae: 0.0997
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0152 - val_mae: 0.0943
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0280 - val_loss: 0.0114 - val_mae: 0.0734
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0282 - val_loss: 0.0110 - val_mae: 0.0747
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0113 - val_mae: 0.0772
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0101 - val_mae: 0.0685
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0077 - val_mae: 0.0505
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0073 - val_mae: 0.0481
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0077 - val_mae: 0.0527
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0086 - val_mae: 0.0546
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0285 - val_loss: 0.0086 - val_mae: 0.0545
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0082 - val_mae: 0.0579
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0083 - val_mae: 0.0568
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0108 - val_mae: 0.0607
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0356 - val_loss: 0.0075 - val_mae: 0.0468
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0078 - val_mae: 0.0415
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0094 - val_mae: 0.0652
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0070 - val_mae: 0.0404
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0290 - val_loss: 0.0083 - val_mae: 0.0547
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Root Mean Squared Error (RMSE): 31.475669071649573
# Mean Absolute Error (MAE): 13.576647980076341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0112 - val_mae: 0.0615
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0094 - val_mae: 0.0486
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0098 - val_mae: 0.0487
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0111 - val_mae: 0.0585
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0114 - val_mae: 0.0616
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0094 - val_mae: 0.0468
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0254 - val_loss: 0.0112 - val_mae: 0.0638
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0300 - val_loss: 0.0100 - val_mae: 0.0523
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0098 - val_mae: 0.0543
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0089 - val_mae: 0.0425
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 0.0100 - val_mae: 0.0478
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - mae: 0.0293 - val_loss: 0.0098 - val_mae: 0.0494
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0257 - val_loss: 0.0094 - val_mae: 0.0478
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0092 - val_mae: 0.0488
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0107 - val_mae: 0.0540
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0285 - val_loss: 0.0105 - val_mae: 0.0504
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 0.0092 - val_mae: 0.0455
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 0.0106 - val_mae: 0.0552
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0089 - val_mae: 0.0418
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 0.0096 - val_mae: 0.0526
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0252 - val_loss: 0.0093 - val_mae: 0.0502
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0099 - val_mae: 0.0466
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0086 - val_mae: 0.0424
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0240 - val_loss: 0.0085 - val_mae: 0.0395
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0089 - val_mae: 0.0445
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0104 - val_mae: 0.0550
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0094 - val_mae: 0.0455
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0091 - val_mae: 0.0427
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0259 - val_loss: 0.0088 - val_mae: 0.0444
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0093 - val_mae: 0.0441
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0260 - val_loss: 0.0092 - val_mae: 0.0462
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0097 - val_mae: 0.0492
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 0.0099 - val_mae: 0.0575
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0273 - val_loss: 0.0103 - val_mae: 0.0554
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0097 - val_mae: 0.0531
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0099 - val_mae: 0.0523
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0100 - val_mae: 0.0493
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 0.0090 - val_mae: 0.0438
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 0.0085 - val_mae: 0.0410
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0099 - val_mae: 0.0402
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0084 - val_mae: 0.0424
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0086 - val_mae: 0.0373
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 0.0084 - val_mae: 0.0414
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0089 - val_mae: 0.0415
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0098 - val_mae: 0.0480
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0101 - val_mae: 0.0528
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0086 - val_mae: 0.0455
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0087 - val_mae: 0.0457
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0101 - val_mae: 0.0464
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0295 - val_loss: 0.0104 - val_mae: 0.0525
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 39.011147680922846
# Mean Absolute Error (MAE): 26.415717034366544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mae: 0.0331 - val_loss: 0.0042 - val_mae: 0.0497
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0342 - val_loss: 0.0055 - val_mae: 0.0572
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0273 - val_loss: 0.0036 - val_mae: 0.0493
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0366 - val_loss: 0.0109 - val_mae: 0.0864
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0388 - val_loss: 0.0065 - val_mae: 0.0691
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0363 - val_loss: 0.0049 - val_mae: 0.0579
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0321 - val_loss: 0.0021 - val_mae: 0.0359
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0336 - val_loss: 0.0029 - val_mae: 0.0461
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0354 - val_loss: 0.0019 - val_mae: 0.0354
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mae: 0.0296 - val_loss: 0.0023 - val_mae: 0.0410
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0335 - val_loss: 0.0020 - val_mae: 0.0360
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0365 - val_loss: 0.0033 - val_mae: 0.0474
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0335 - val_loss: 0.0041 - val_mae: 0.0551
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024 - mae: 0.0314 - val_loss: 0.0036 - val_mae: 0.0508
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0293 - val_loss: 8.7491e-04 - val_mae: 0.0250
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0269 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0235 - val_loss: 0.0083 - val_mae: 0.0772
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0346 - val_loss: 0.0085 - val_mae: 0.0788
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0379 - val_loss: 0.0016 - val_mae: 0.0303
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0303 - val_loss: 0.0025 - val_mae: 0.0426
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0282 - val_loss: 0.0017 - val_mae: 0.0352
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0291 - val_loss: 0.0013 - val_mae: 0.0306
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0020 - val_mae: 0.0381
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0298 - val_loss: 0.0039 - val_mae: 0.0521
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0345 - val_loss: 0.0029 - val_mae: 0.0436
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0281 - val_loss: 0.0032 - val_mae: 0.0499
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 0.0024 - val_mae: 0.0422
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0270 - val_loss: 0.0010 - val_mae: 0.0262
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0298 - val_loss: 5.3941e-04 - val_mae: 0.0180
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0272 - val_loss: 9.3541e-04 - val_mae: 0.0253
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0275 - val_loss: 0.0019 - val_mae: 0.0361
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0282 - val_loss: 7.1430e-04 - val_mae: 0.0214
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0289 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0266 - val_loss: 7.4991e-04 - val_mae: 0.0223
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0274 - val_loss: 9.7695e-04 - val_mae: 0.0260
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mae: 0.0281 - val_loss: 8.9609e-04 - val_mae: 0.0243
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0339 - val_loss: 7.5989e-04 - val_mae: 0.0221
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0269 - val_loss: 9.5451e-04 - val_mae: 0.0256
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 7.3633e-04 - val_mae: 0.0216
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0291 - val_loss: 9.8081e-04 - val_mae: 0.0257
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mae: 0.0301 - val_loss: 0.0011 - val_mae: 0.0261
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0246 - val_loss: 5.1438e-04 - val_mae: 0.0177
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0276 - val_loss: 9.9968e-04 - val_mae: 0.0255
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mae: 0.0279 - val_loss: 0.0035 - val_mae: 0.0500
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0411 - val_loss: 0.0034 - val_mae: 0.0474
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0306 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0255 - val_loss: 0.0015 - val_mae: 0.0326
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0287 - val_loss: 0.0015 - val_mae: 0.0293
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mae: 0.0273 - val_loss: 9.7649e-04 - val_mae: 0.0249
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Root Mean Squared Error (RMSE): 8.799586544750898
# Mean Absolute Error (MAE): 7.22394724422031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
