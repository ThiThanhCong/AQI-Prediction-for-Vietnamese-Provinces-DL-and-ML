# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Conv1D, Add, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Load the data
df = pd.read_csv(r'C:\Users\ASUS\Desktop\ptdl\BacNinh.csv')
print(df.columns)

# Preprocess the data
df['date'] = pd.to_datetime(df['date'])  # Chuyển đổi cột date thành định dạng thời gian
df.set_index('date', inplace=True)  # Đặt cột date làm index
df = df.loc['2019-03-01':'2024-03-01']  # Chọn phạm vi thời gian cụ thể

# Check for null values and drop them
null_count = df.isnull().sum()
print(null_count)
df = df.dropna()

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['AQI']])

# Prepare data function
def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

timesteps = 10  # Độ dài của cửa sổ trượt
X, y = prepare_data(scaled_data, timesteps)



# Build the model
input_layer = Input(shape=(timesteps, 1))
x = LSTM(64, return_sequences=True)(input_layer)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = Conv1D(64, kernel_size=2, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=1, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(1, kernel_size=3, padding='same')(x)
x = Add()([x, input_layer])
output_layer = Activation('tanh')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Index(['Unnamed: 0', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'AQI'], dtype='object')
# Unnamed: 0    0
# pm25          0
# pm10          0
# o3            0
# no2           0
# so2           0
# co            0
# AQI           0
# dtype: int64
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 10, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ (None, 10, 64)            │          16,896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 10, 64)            │          12,352 │ lstm[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 10, 64)            │           8,256 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 10, 64)            │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 10, 64)            │           4,160 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 10, 64)            │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 10, 64)            │          12,352 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 10, 64)            │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 10, 1)             │             193 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 10, 1)             │               0 │ conv1d_4[0][0],            │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 10, 1)             │               0 │ add[0][0]                  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 54,977 (214.75 KB)
#  Trainable params: 54,593 (213.25 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Assuming df, model, scaler, X_train, y_train, X_test, y_test, and timesteps are already defined
def custom_round(number):
    if number >= 0:
        return int(number + 0.5)  # Làm tròn lên
    else:
        return int(number - 0.5)  # Làm tròn xuống
train_sizes = [0.7, 0.8, 0.9]
for train_size_ratio in train_sizes:
    # Split data into training and testing sets
    train_size = int(len(X) * train_size_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    # Reshape data to match model input
    X_train = np.reshape(X_train, (X_train.shape[0], timesteps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], timesteps, 1))
    
    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Inverse transform the predictions and true values
    y_pred_inverse = scaler.inverse_transform(y_pred[:, -1, 0].reshape(-1, 1))
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_train_inverse = scaler.inverse_transform(y_train.reshape(-1, 1))
    
    # Calculate error metrics
    rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    
    # Extend the index by 30 days
    last_index = df.index[-1]
    
    if isinstance(df.index, pd.DatetimeIndex):
        new_index = pd.date_range(start=last_index, periods=31, freq='D')[1:]
    elif isinstance(df.index, pd.RangeIndex):
        new_index = pd.RangeIndex(start=last_index + 1, stop=last_index + 31, step=1)
    
    
    # Create an array of 30 consecutive integers starting from the last index
    if isinstance(df.index, pd.DatetimeIndex):
        x_next_30_days = np.array(range(1, 31)).reshape(-1, 1)
    elif isinstance(df.index, pd.RangeIndex):
        x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
    
    # Predict the AQI for the next 30 days
    y_next_30_days = model.predict(x_next_30_days)
    y_next_30_days_flat = scaler.inverse_transform(y_next_30_days[:, -1, 0].reshape(-1, 1)).flatten()
    # Plot the results
    plt.figure(figsize=(12, 6))
    plt.plot(df.index[:len(y_train_inverse)], y_train_inverse, label='Train')
    plt.plot(df.index[-len(y_test_inverse):], y_test_inverse, label='Actual AQI')
    plt.plot(df.index[-len(y_test_inverse):], y_pred_inverse, label='Predicted AQI')
    plt.plot(new_index, y_next_30_days_flat, label='Predicted Next 30 Days')
    plt.xlabel('Date')
    plt.ylabel('AQI')
    plt.title(f'Actual vs Predicted AQI split {custom_round(train_size_ratio * 10)}:{custom_round((1-train_size_ratio)*10)}')
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.2062 - mae: 0.3390 - val_loss: 0.0328 - val_mae: 0.1423
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0362 - mae: 0.1450 - val_loss: 0.0366 - val_mae: 0.1555
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0327 - mae: 0.1394 - val_loss: 0.0432 - val_mae: 0.1725
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0272 - mae: 0.1263 - val_loss: 0.0467 - val_mae: 0.1807
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0238 - mae: 0.1192 - val_loss: 0.0552 - val_mae: 0.1985
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.1232 - val_loss: 0.0566 - val_mae: 0.2011
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0259 - mae: 0.1255 - val_loss: 0.0561 - val_mae: 0.2000
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.1213 - val_loss: 0.0551 - val_mae: 0.1978
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249 - mae: 0.1215 - val_loss: 0.0590 - val_mae: 0.2054
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0231 - mae: 0.1161 - val_loss: 0.0571 - val_mae: 0.2017
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0267 - mae: 0.1263 - val_loss: 0.0532 - val_mae: 0.1938
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0235 - mae: 0.1156 - val_loss: 0.0532 - val_mae: 0.1934
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0227 - mae: 0.1134 - val_loss: 0.0540 - val_mae: 0.1946
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0224 - mae: 0.1136 - val_loss: 0.0523 - val_mae: 0.1906
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0212 - mae: 0.1120 - val_loss: 0.0502 - val_mae: 0.1864
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0220 - mae: 0.1117 - val_loss: 0.0474 - val_mae: 0.1758
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mae: 0.1080 - val_loss: 0.0451 - val_mae: 0.1725
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0224 - mae: 0.1139 - val_loss: 0.0522 - val_mae: 0.1888
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - mae: 0.1122 - val_loss: 0.0466 - val_mae: 0.1746
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0219 - mae: 0.1095 - val_loss: 0.0444 - val_mae: 0.1691
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0232 - mae: 0.1154 - val_loss: 0.0359 - val_mae: 0.1517
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0227 - mae: 0.1152 - val_loss: 0.0357 - val_mae: 0.1496
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0223 - mae: 0.1119 - val_loss: 0.0334 - val_mae: 0.1440
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0223 - mae: 0.1126 - val_loss: 0.0314 - val_mae: 0.1389
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mae: 0.1078 - val_loss: 0.0299 - val_mae: 0.1328
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0209 - mae: 0.1088 - val_loss: 0.0297 - val_mae: 0.1339
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0233 - mae: 0.1187 - val_loss: 0.0287 - val_mae: 0.1303
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0194 - mae: 0.1044 - val_loss: 0.0329 - val_mae: 0.1406
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0202 - mae: 0.1076 - val_loss: 0.0299 - val_mae: 0.1346
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0203 - mae: 0.1075 - val_loss: 0.0268 - val_mae: 0.1285
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mae: 0.1078 - val_loss: 0.0291 - val_mae: 0.1342
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0201 - mae: 0.1075 - val_loss: 0.0312 - val_mae: 0.1408
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0192 - mae: 0.1044 - val_loss: 0.0325 - val_mae: 0.1416
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0207 - mae: 0.1080 - val_loss: 0.0338 - val_mae: 0.1419
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188 - mae: 0.1021 - val_loss: 0.0266 - val_mae: 0.1257
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0202 - mae: 0.1060 - val_loss: 0.0288 - val_mae: 0.1305
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0218 - mae: 0.1093 - val_loss: 0.0294 - val_mae: 0.1321
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0183 - mae: 0.0999 - val_loss: 0.0286 - val_mae: 0.1304
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - mae: 0.1036 - val_loss: 0.0294 - val_mae: 0.1312
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0213 - mae: 0.1092 - val_loss: 0.0299 - val_mae: 0.1307
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0205 - mae: 0.1063 - val_loss: 0.0279 - val_mae: 0.1287
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0205 - mae: 0.1061 - val_loss: 0.0288 - val_mae: 0.1289
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0194 - mae: 0.1060 - val_loss: 0.0270 - val_mae: 0.1256
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0206 - mae: 0.1064 - val_loss: 0.0299 - val_mae: 0.1319
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - mae: 0.1015 - val_loss: 0.0308 - val_mae: 0.1330
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - mae: 0.1046 - val_loss: 0.0290 - val_mae: 0.1290
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186 - mae: 0.1012 - val_loss: 0.0348 - val_mae: 0.1445
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - mae: 0.1117 - val_loss: 0.0296 - val_mae: 0.1331
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0214 - mae: 0.1090 - val_loss: 0.0310 - val_mae: 0.1388
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mae: 0.1066 - val_loss: 0.0285 - val_mae: 0.1286
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Root Mean Squared Error (RMSE): 30.426020092682133
# Mean Absolute Error (MAE): 23.481379431589193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0183 - mae: 0.1004 - val_loss: 0.0376 - val_mae: 0.1497
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0198 - mae: 0.1057 - val_loss: 0.0521 - val_mae: 0.1786
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0182 - mae: 0.1003 - val_loss: 0.0406 - val_mae: 0.1586
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0203 - mae: 0.1084 - val_loss: 0.0407 - val_mae: 0.1543
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0179 - mae: 0.0985 - val_loss: 0.0376 - val_mae: 0.1476
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - mae: 0.0979 - val_loss: 0.0442 - val_mae: 0.1656
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179 - mae: 0.0992 - val_loss: 0.0386 - val_mae: 0.1503
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - mae: 0.0982 - val_loss: 0.0376 - val_mae: 0.1528
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0186 - mae: 0.1011 - val_loss: 0.0428 - val_mae: 0.1627
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - mae: 0.1120 - val_loss: 0.0409 - val_mae: 0.1585
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - mae: 0.0991 - val_loss: 0.0363 - val_mae: 0.1477
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - mae: 0.1020 - val_loss: 0.0320 - val_mae: 0.1405
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - mae: 0.1033 - val_loss: 0.0327 - val_mae: 0.1436
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0188 - mae: 0.1022 - val_loss: 0.0358 - val_mae: 0.1468
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185 - mae: 0.1013 - val_loss: 0.0404 - val_mae: 0.1573
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - mae: 0.0986 - val_loss: 0.0494 - val_mae: 0.1740
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mae: 0.0967 - val_loss: 0.0372 - val_mae: 0.1485
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0178 - mae: 0.0976 - val_loss: 0.0430 - val_mae: 0.1589
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - mae: 0.0972 - val_loss: 0.0402 - val_mae: 0.1518
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0180 - mae: 0.0986 - val_loss: 0.0390 - val_mae: 0.1496
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - mae: 0.1074 - val_loss: 0.0423 - val_mae: 0.1604
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - mae: 0.1038 - val_loss: 0.0385 - val_mae: 0.1490
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - mae: 0.1026 - val_loss: 0.0389 - val_mae: 0.1566
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187 - mae: 0.1019 - val_loss: 0.0415 - val_mae: 0.1564
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183 - mae: 0.1003 - val_loss: 0.0343 - val_mae: 0.1444
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186 - mae: 0.1034 - val_loss: 0.0360 - val_mae: 0.1490
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0188 - mae: 0.1019 - val_loss: 0.0356 - val_mae: 0.1447
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0179 - mae: 0.0993 - val_loss: 0.0365 - val_mae: 0.1490
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - mae: 0.0974 - val_loss: 0.0447 - val_mae: 0.1638
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0182 - mae: 0.1007 - val_loss: 0.0374 - val_mae: 0.1491
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0169 - mae: 0.0961 - val_loss: 0.0438 - val_mae: 0.1628
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - mae: 0.1015 - val_loss: 0.0433 - val_mae: 0.1585
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189 - mae: 0.1037 - val_loss: 0.0352 - val_mae: 0.1440
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - mae: 0.1010 - val_loss: 0.0364 - val_mae: 0.1500
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0178 - mae: 0.1009 - val_loss: 0.0396 - val_mae: 0.1538
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0190 - mae: 0.1022 - val_loss: 0.0348 - val_mae: 0.1436
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - mae: 0.0977 - val_loss: 0.0382 - val_mae: 0.1514
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0177 - mae: 0.0992 - val_loss: 0.0334 - val_mae: 0.1424
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - mae: 0.1022 - val_loss: 0.0336 - val_mae: 0.1415
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0181 - mae: 0.0986 - val_loss: 0.0357 - val_mae: 0.1477
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - mae: 0.0971 - val_loss: 0.0342 - val_mae: 0.1447
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0967 - val_loss: 0.0331 - val_mae: 0.1415
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0175 - mae: 0.0982 - val_loss: 0.0362 - val_mae: 0.1495
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0182 - mae: 0.1003 - val_loss: 0.0394 - val_mae: 0.1562
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0178 - mae: 0.0995 - val_loss: 0.0426 - val_mae: 0.1616
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - mae: 0.1026 - val_loss: 0.0332 - val_mae: 0.1437
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165 - mae: 0.0955 - val_loss: 0.0420 - val_mae: 0.1603
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - mae: 0.0974 - val_loss: 0.0393 - val_mae: 0.1568
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0184 - mae: 0.1004 - val_loss: 0.0357 - val_mae: 0.1437
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0177 - mae: 0.0989 - val_loss: 0.0379 - val_mae: 0.1501
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 32.82129512441442
# Mean Absolute Error (MAE): 25.12195197492838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 1/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - mae: 0.1029 - val_loss: 0.0402 - val_mae: 0.1607
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - mae: 0.1015 - val_loss: 0.0432 - val_mae: 0.1659
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0964 - val_loss: 0.0496 - val_mae: 0.1807
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0168 - mae: 0.0967 - val_loss: 0.0399 - val_mae: 0.1587
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mae: 0.0973 - val_loss: 0.0435 - val_mae: 0.1666
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172 - mae: 0.0978 - val_loss: 0.0424 - val_mae: 0.1695
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176 - mae: 0.1004 - val_loss: 0.0473 - val_mae: 0.1769
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0192 - mae: 0.1045 - val_loss: 0.0482 - val_mae: 0.1795
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - mae: 0.0968 - val_loss: 0.0446 - val_mae: 0.1715
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mae: 0.0977 - val_loss: 0.0423 - val_mae: 0.1653
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - mae: 0.0999 - val_loss: 0.0407 - val_mae: 0.1603
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - mae: 0.1037 - val_loss: 0.0460 - val_mae: 0.1744
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mae: 0.0956 - val_loss: 0.0459 - val_mae: 0.1757
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - mae: 0.1005 - val_loss: 0.0400 - val_mae: 0.1594
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - mae: 0.0997 - val_loss: 0.0399 - val_mae: 0.1568
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - mae: 0.0966 - val_loss: 0.0412 - val_mae: 0.1599
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0955 - val_loss: 0.0405 - val_mae: 0.1589
# Epoch 18/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mae: 0.1005 - val_loss: 0.0384 - val_mae: 0.1540
# Epoch 19/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0166 - mae: 0.0934 - val_loss: 0.0409 - val_mae: 0.1626
# Epoch 20/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0166 - mae: 0.0949 - val_loss: 0.0491 - val_mae: 0.1788
# Epoch 21/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0170 - mae: 0.0955 - val_loss: 0.0388 - val_mae: 0.1578
# Epoch 22/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164 - mae: 0.0942 - val_loss: 0.0522 - val_mae: 0.1871
# Epoch 23/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - mae: 0.0977 - val_loss: 0.0404 - val_mae: 0.1602
# Epoch 24/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mae: 0.0960 - val_loss: 0.0404 - val_mae: 0.1562
# Epoch 25/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - mae: 0.0959 - val_loss: 0.0403 - val_mae: 0.1601
# Epoch 26/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - mae: 0.0968 - val_loss: 0.0444 - val_mae: 0.1665
# Epoch 27/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mae: 0.0953 - val_loss: 0.0379 - val_mae: 0.1531
# Epoch 28/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0164 - mae: 0.0948 - val_loss: 0.0389 - val_mae: 0.1565
# Epoch 29/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - mae: 0.0976 - val_loss: 0.0421 - val_mae: 0.1640
# Epoch 30/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161 - mae: 0.0941 - val_loss: 0.0433 - val_mae: 0.1674
# Epoch 31/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0160 - mae: 0.0947 - val_loss: 0.0378 - val_mae: 0.1543
# Epoch 32/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - mae: 0.0970 - val_loss: 0.0413 - val_mae: 0.1585
# Epoch 33/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0159 - mae: 0.0937 - val_loss: 0.0384 - val_mae: 0.1545
# Epoch 34/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159 - mae: 0.0944 - val_loss: 0.0411 - val_mae: 0.1591
# Epoch 35/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0163 - mae: 0.0945 - val_loss: 0.0444 - val_mae: 0.1675
# Epoch 36/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165 - mae: 0.0968 - val_loss: 0.0392 - val_mae: 0.1569
# Epoch 37/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0950 - val_loss: 0.0385 - val_mae: 0.1536
# Epoch 38/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - mae: 0.0945 - val_loss: 0.0401 - val_mae: 0.1587
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - mae: 0.0975 - val_loss: 0.0376 - val_mae: 0.1551
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - mae: 0.0943 - val_loss: 0.0482 - val_mae: 0.1791
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - mae: 0.0969 - val_loss: 0.0449 - val_mae: 0.1725
# Epoch 42/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0151 - mae: 0.0905 - val_loss: 0.0456 - val_mae: 0.1695
# Epoch 43/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - mae: 0.0920 - val_loss: 0.0545 - val_mae: 0.1901
# Epoch 44/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mae: 0.0980 - val_loss: 0.0450 - val_mae: 0.1681
# Epoch 45/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0169 - mae: 0.0974 - val_loss: 0.0443 - val_mae: 0.1710
# Epoch 46/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - mae: 0.0980 - val_loss: 0.0425 - val_mae: 0.1635
# Epoch 47/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - mae: 0.0953 - val_loss: 0.0410 - val_mae: 0.1644
# Epoch 48/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - mae: 0.0952 - val_loss: 0.0385 - val_mae: 0.1557
# Epoch 49/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - mae: 0.0930 - val_loss: 0.0391 - val_mae: 0.1562
# Epoch 50/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161 - mae: 0.0929 - val_loss: 0.0398 - val_mae: 0.1594
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 39.34880721380635
# Mean Absolute Error (MAE): 31.970210272690345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
