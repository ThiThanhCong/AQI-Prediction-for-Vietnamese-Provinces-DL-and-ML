# %%
# 1. Import thư viện cần thiết
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# 2. Đọc file csv và gắn index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/Dataset/Test/VietTri.csv')

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] < '2024-06-01']

# %%
# 10. Generate future predictions
def predict_future(model, data, time_step, future_days, scaler):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# %%
# 5. Hàm Create Dataset
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def train_test_split_and_predict(tran_ratio=0.7):
  df1 = df.reset_index()['AQI']
# 3. Scaler data
  scaler = MinMaxScaler(feature_range=(0, 1))
  df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))
# 4. Chia train test
  train_size = int(tran_ratio * len(df1))
  test_size = len(df1) - train_size
  train_data = df1[:train_size]
  test_data = df1[train_size:]
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
  time_step = 100
  X_train, y_train = create_dataset(train_data, time_step)
  X_test, y_test = create_dataset(test_data, time_step)
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
  X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
  X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
# 8. Define GRU Model
  model = Sequential()
  model.add(GRU(64, input_shape=(time_step, 1)))
  model.add(Dense(1))
  model.compile(optimizer='adam', loss='mean_squared_error')
# 9. Fit mô hình với dữ liệu train
  model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)

# Predict on train and test data
  train_predict = model.predict(X_train)
  test_predict = model.predict(X_test)

# Inverse transform predictions
  train_predict = scaler.inverse_transform(train_predict)
  test_predict = scaler.inverse_transform(test_predict)

# Predict for 30, 60, 90 days
  future_30_days = predict_future(model, df1, time_step, 30, scaler)
  future_60_days = predict_future(model, df1, time_step, 60, scaler)
  future_90_days = predict_future(model, df1, time_step, 90, scaler)
  plt.figure(figsize=(15, 8))

  # Plot train data
  plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
  plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
  plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
  plt.plot(np.arange(len(df1), len(df1) + 30), future_30_days, label="30 Days Prediction")

    # Add labels and legend
  plt.xlabel('Days')
  plt.ylabel('AQI')
  plt.title(f'AQI Predictions - 30 Days prediction')
  plt.legend()
  plt.show()

  # Plot train data
  plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
  plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
  plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
  plt.plot(np.arange(len(df1), len(df1) + 60), future_60_days, label="60 Days Prediction")

    # Add labels and legend
  plt.xlabel('Days')
  plt.ylabel('AQI')
  plt.title(f'AQI Predictions - 60 Days prediction')
  plt.legend()
  plt.show()

  # Plot train data
  plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
  plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
  plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
  plt.plot(np.arange(len(df1), len(df1) + 90), future_90_days, label="90 Days Prediction")

    # Add labels and legend
  plt.xlabel('Days')
  plt.ylabel('AQI')
  plt.title(f'AQI Predictions - 90 Days prediction')
  plt.legend()
  plt.show()

# Calculate MAE, RMSE, and MAPE for test predictions
  mae = mean_absolute_error(y_test, test_predict)
  rmse = np.sqrt(mean_squared_error(y_test, test_predict))
  mape = mean_absolute_percentage_error(y_test, test_predict)

  print(f'MAE: {mae}')
  print(f'RMSE: {rmse}')
  print(f'MAPE: {mape}')

# %%
train_test_split_and_predict(0.7)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 88ms/step - loss: 0.0027 - val_loss: 9.7091e-04
# Epoch 2/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0016 - val_loss: 9.7128e-04
# Epoch 3/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0014 - val_loss: 8.5229e-04
# Epoch 4/100
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0014 - val_loss: 8.3577e-04
# Epoch 5/100
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0013 - val_loss: 9.0136e-04
# Epoch 6/100
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0013 - val_loss: 8.2827e-04
# Epoch 7/100
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0013 - val_loss: 8.1151e-04
# Epoch 8/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0013 - val_loss: 8.6864e-04
# Epoch 9/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0013 - val_loss: 8.2864e-04
# Epoch 10/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.0013 - val_loss: 8.1691e-04
# Epoch 11/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0013 - val_loss: 9.5609e-04
# Epoch 12/100
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0013 - val_loss: 7.9325e-04
# Epoch 13/100
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0013 - val_loss: 8.3251e-04
# Epoch 14/100
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0014 - val_loss: 7.8231e-04
# Epoch 15/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0013 - val_loss: 8.0004e-04
# Epoch 16/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0013 - val_loss: 7.9553e-04
# Epoch 17/100
# 25/25 [==============================] - 2s 101ms/step - loss: 0.0013 - val_loss: 7.8558e-04
# Epoch 18/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0013 - val_loss: 7.8600e-04
# Epoch 19/100
# 25/25 [==============================] - 2s 74ms/step - loss: 0.0013 - val_loss: 7.7744e-04
# Epoch 20/100
# 25/25 [==============================] - 2s 99ms/step - loss: 0.0013 - val_loss: 8.0317e-04
# Epoch 21/100
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0014 - val_loss: 8.7258e-04
# Epoch 22/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0013 - val_loss: 7.8994e-04
# Epoch 23/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.0013 - val_loss: 7.8326e-04
# Epoch 24/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.0013 - val_loss: 7.8856e-04
# Epoch 25/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.0013 - val_loss: 7.7662e-04
# Epoch 26/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0013 - val_loss: 7.7525e-04
# Epoch 27/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0013 - val_loss: 7.7248e-04
# Epoch 28/100
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0013 - val_loss: 8.0013e-04
# Epoch 29/100
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0013 - val_loss: 7.7589e-04
# Epoch 30/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0013 - val_loss: 8.1188e-04
# Epoch 31/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0013 - val_loss: 7.7710e-04
# Epoch 32/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0013 - val_loss: 7.7111e-04
# Epoch 33/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0013 - val_loss: 7.7179e-04
# Epoch 34/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0013 - val_loss: 7.8044e-04
# Epoch 35/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0013 - val_loss: 7.7398e-04
# Epoch 36/100
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0012 - val_loss: 7.9782e-04
# Epoch 37/100
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0013 - val_loss: 7.7293e-04
# Epoch 38/100
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0013 - val_loss: 7.7659e-04
# Epoch 39/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.0012 - val_loss: 7.7681e-04
# Epoch 40/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.0012 - val_loss: 7.6819e-04
# Epoch 41/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.0012 - val_loss: 7.6104e-04
# Epoch 42/100
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0012 - val_loss: 7.6666e-04
# Epoch 43/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0012 - val_loss: 7.9535e-04
# Epoch 44/100
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0012 - val_loss: 7.7718e-04
# Epoch 45/100
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0012 - val_loss: 8.0565e-04
# Epoch 46/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0012 - val_loss: 7.6902e-04
# Epoch 47/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0012 - val_loss: 7.6333e-04
# Epoch 48/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.0012 - val_loss: 7.5980e-04
# Epoch 49/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.
100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 3.7640e-04
# Epoch 91/100
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 3.7797e-04
# Epoch 92/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0012 - val_loss: 3.7895e-04
# Epoch 93/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0012 - val_loss: 3.8422e-04
# Epoch 94/100
# 28/28 [==============================] - 2s 78ms/step - loss: 0.0012 - val_loss: 3.9474e-04
# Epoch 95/100
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0012 - val_loss: 3.8219e-04
# Epoch 96/100
# 28/28 [==============================] - 2s 70ms/step - loss: 0.0012 - val_loss: 4.3436e-04
# Epoch 97/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 3.8046e-04
# Epoch 98/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0012 - val_loss: 3.8582e-04
# Epoch 99/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 3.8094e-04
# Epoch 100/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 3.8709e-04
# 56/56 [==============================] - 2s 19ms/step
# 12/12 [==============================] - 0s 19ms/step
# MAE: 52.32308081788388
# RMSE: 56.05846981271215
# MAPE: 1614.0239563493587
# Epoch 1/100
# 32/32 [==============================] - 6s 116ms/step - loss: 0.0019 - val_loss: 3.9583e-04
# Epoch 2/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.0013 - val_loss: 3.9868e-04
# Epoch 3/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.0013 - val_loss: 3.2132e-04
# Epoch 4/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0012 - val_loss: 3.2157e-04
# Epoch 5/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 3.0854e-04
# Epoch 6/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 3.0248e-04
# Epoch 7/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0013 - val_loss: 2.9688e-04
# Epoch 8/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 3.0436e-04
# Epoch 9/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 3.1211e-04
# Epoch 10/100
# 32/32 [==============================] - 3s 80ms/step - loss: 0.0012 - val_loss: 3.0926e-04
# Epoch 11/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.0012 - val_loss: 2.9484e-04
# Epoch 12/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0012 - val_loss: 2.9428e-04
# Epoch 13/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0012 - val_loss: 2.9324e-04
# Epoch 14/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 2.9833e-04
# Epoch 15/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.9352e-04
# Epoch 16/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 3.9029e-04
# Epoch 17/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.0012 - val_loss: 2.9872e-04
# Epoch 18/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0012 - val_loss: 3.0078e-04
# Epoch 19/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.0012 - val_loss: 2.9046e-04
# Epoch 20/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.8741e-04
# Epoch 21/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 2.9163e-04
# Epoch 22/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 3.6537e-04
# Epoch 23/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0013 - val_loss: 4.6553e-04
# Epoch 24/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.0012 - val_loss: 3.9132e-04
# Epoch 25/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.0012 - val_loss: 3.1811e-04
# Epoch 26/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0012 - val_loss: 2.9161e-04
# Epoch 27/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 3.0353e-04
# Epoch 28/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 2.9606e-04
# Epoch 29/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 2.9984e-04
# Epoch 30/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.0012 - val_loss: 3.8628e-04
# Epoch 31/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.8915e-04
# Epoch 32/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.0012 - val_loss: 2.9460e-04
# Epoch 33/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0011 - val_loss: 3.6504e-04
# Epoch 34/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.8875e-04
# Epoch 35/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0012 - val_loss: 2.9760e-04
# Epoch 36/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.9234e-04
# Epoch 37/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 3.1208e-04
# Epoch 38/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 2.9697e-04
# Epoch 39/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0012 - val_loss: 3.3598e-04
# Epoch 40/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0012 - val_loss: 3.1339e-04
# Epoch 41/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.0011 - val_loss: 2.9158e-04
# Epoch 42/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 2.9753e-04
# Epoch 43/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0012 - val_loss: 2.8813e-04
# Epoch 44/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 2.9226e-04
# Epoch 45/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0012 - val_loss: 2.8968e-04
# Epoch 46/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.0011 - val_loss: 2.8942e-04
# Epoch 47/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0011 - val_loss: 3.0838e-04
# Epoch 48/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.0011 - val_loss: 2.8672e-04
# Epoch 49/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9576e-04
# Epoch 50/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 3.0047e-04
# Epoch 51/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 2.9441e-04
# Epoch 52/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0160e-04
# Epoch 53/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.0011 - val_loss: 3.3017e-04
# Epoch 54/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0011 - val_loss: 2.9550e-04
# Epoch 55/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.0011 - val_loss: 2.9319e-04
# Epoch 56/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0184e-04
# Epoch 57/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.0011 - val_loss: 2.9341e-04
# Epoch 58/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0011 - val_loss: 3.1448e-04
# Epoch 59/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0011 - val_loss: 2.9948e-04
# Epoch 60/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.0011 - val_loss: 2.9653e-04
# Epoch 61/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0011 - val_loss: 3.2077e-04
# Epoch 62/100
# 32/32 [==============================] - 2s 71ms/step - loss: 0.0011 - val_loss: 2.8830e-04
# Epoch 63/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.4544e-04
# Epoch 64/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0303e-04
# Epoch 65/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 3.4380e-04
# Epoch 66/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0679e-04
# Epoch 67/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.0011 - val_loss: 2.8787e-04
# Epoch 68/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0011 - val_loss: 3.1833e-04
# Epoch 69/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.0011 - val_loss: 3.0298e-04
# Epoch 70/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0263e-04
# Epoch 71/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 3.1361e-04
# Epoch 72/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 3.3027e-04
# Epoch 73/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 2.9391e-04
# Epoch 74/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9686e-04
# Epoch 75/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0011 - val_loss: 3.3284e-04
# Epoch 76/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0011 - val_loss: 2.9299e-04
# Epoch 77/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0011 - val_loss: 2.8919e-04
# Epoch 78/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.6918e-04
# Epoch 79/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0011 - val_loss: 2.9174e-04
# Epoch 80/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 2.9318e-04
# Epoch 81/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0717e-04
# Epoch 82/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.0011 - val_loss: 3.5346e-04
# Epoch 83/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0011 - val_loss: 3.0616e-04
# Epoch 84/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0011 - val_loss: 2.8890e-04
# Epoch 85/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.8968e-04
# Epoch 86/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.0011 - val_loss: 3.3110e-04
# Epoch 87/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9914e-04
# Epoch 88/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.0011 - val_loss: 2.8913e-04
# Epoch 89/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.0011 - val_loss: 3.4142e-04
# Epoch 90/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0011 - val_loss: 3.0209e-04
# Epoch 91/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.0011 - val_loss: 2.8842e-04
# Epoch 92/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.8677e-04
# Epoch 93/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.0011 - val_loss: 2.8802e-04
# Epoch 94/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 3.0298e-04
# Epoch 95/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9430e-04
# Epoch 96/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0011 - val_loss: 2.9628e-04
# Epoch 97/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0011 - val_loss: 2.8831e-04
# Epoch 98/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.0011 - val_loss: 3.0680e-04
# Epoch 99/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9770e-04
# Epoch 100/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 2.9020e-04
# 63/63 [==============================] - 2s 19ms/step
# 5/5 [==============================] - 0s 14ms/step
# MAE: 51.558916102598786
# RMSE: 52.884029935095214
# MAPE: 1439.8088828771224
