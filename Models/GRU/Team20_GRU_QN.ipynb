# %%
# 1. Import thư viện cần thiết
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU
import seaborn as sns

# %%
# 2. Đọc file csv và gắn index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/Dataset/QuangNinh.csv')

# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y')
df = df[df['date'] < '2024-03-01']

# Create AQI column with the maximum value from the specified columns
df['AQI'] = df[['pm25', 'pm10', 'o3', 'no2', 'so2', 'co']].max(axis=1)

df.head()
# Out:
#    Unnamed: 0       date  pm25  pm10  o3  no2  so2  co  AQI
# 0           1 2021-02-14    20     6  28    5   12   5   28
# 1           2 2021-02-15     9    14  28    9   12   5   28
# 2           3 2021-02-16    18    17  26    9   12   6   26
# 3           4 2021-02-17    20    24  26   15   12   6   26
# 4           5 2021-02-18    28    29  38   16   12   6   38

# %%
df1 = df.reset_index()['AQI']
# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 8. Define GRU Model
model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)

# Predict on train and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 3s 120ms/step - loss: 0.0014 - val_loss: 0.0068
# Epoch 2/100
# 9/9 [==============================] - 1s 61ms/step - loss: 8.5450e-04 - val_loss: 0.0066
# Epoch 3/100
# 9/9 [==============================] - 1s 60ms/step - loss: 7.7092e-04 - val_loss: 0.0064
# Epoch 4/100
# 9/9 [==============================] - 1s 59ms/step - loss: 7.0765e-04 - val_loss: 0.0063
# Epoch 5/100
# 9/9 [==============================] - 1s 61ms/step - loss: 6.8277e-04 - val_loss: 0.0062
# Epoch 6/100
# 9/9 [==============================] - 1s 59ms/step - loss: 6.5616e-04 - val_loss: 0.0062
# Epoch 7/100
# 9/9 [==============================] - 0s 56ms/step - loss: 6.3347e-04 - val_loss: 0.0061
# Epoch 8/100
# 9/9 [==============================] - 1s 62ms/step - loss: 6.2599e-04 - val_loss: 0.0061
# Epoch 9/100
# 9/9 [==============================] - 1s 60ms/step - loss: 6.1642e-04 - val_loss: 0.0061
# Epoch 10/100
# 9/9 [==============================] - 1s 93ms/step - loss: 6.0042e-04 - val_loss: 0.0060
# Epoch 11/100
# 9/9 [==============================] - 1s 92ms/step - loss: 5.9204e-04 - val_loss: 0.0059
# Epoch 12/100
# 9/9 [==============================] - 1s 104ms/step - loss: 5.8032e-04 - val_loss: 0.0059
# Epoch 13/100
# 9/9 [==============================] - 1s 103ms/step - loss: 5.8544e-04 - val_loss: 0.0059
# Epoch 14/100
# 9/9 [==============================] - 1s 96ms/step - loss: 5.7847e-04 - val_loss: 0.0058
# Epoch 15/100
# 9/9 [==============================] - 1s 103ms/step - loss: 5.6089e-04 - val_loss: 0.0057
# Epoch 16/100
# 9/9 [==============================] - 1s 61ms/step - loss: 5.5417e-04 - val_loss: 0.0057
# Epoch 17/100
# 9/9 [==============================] - 1s 58ms/step - loss: 5.4617e-04 - val_loss: 0.0056
# Epoch 18/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.3988e-04 - val_loss: 0.0056
# Epoch 19/100
# 9/9 [==============================] - 1s 59ms/step - loss: 5.5706e-04 - val_loss: 0.0056
# Epoch 20/100
# 9/9 [==============================] - 1s 62ms/step - loss: 5.3768e-04 - val_loss: 0.0055
# Epoch 21/100
# 9/9 [==============================] - 1s 59ms/step - loss: 5.2505e-04 - val_loss: 0.0055
# Epoch 22/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.4021e-04 - val_loss: 0.0055
# Epoch 23/100
# 9/9 [==============================] - 1s 57ms/step - loss: 5.4427e-04 - val_loss: 0.0054
# Epoch 24/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.3845e-04 - val_loss: 0.0053
# Epoch 25/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.4463e-04 - val_loss: 0.0054
# Epoch 26/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.2441e-04 - val_loss: 0.0053
# Epoch 27/100
# 9/9 [==============================] - 1s 57ms/step - loss: 5.0932e-04 - val_loss: 0.0052
# Epoch 28/100
# 9/9 [==============================] - 1s 60ms/step - loss: 5.0396e-04 - val_loss: 0.0052
# Epoch 29/100
# 9/9 [==============================] - 0s 56ms/step - loss: 4.9611e-04 - val_loss: 0.0052
# Epoch 30/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.9785e-04 - val_loss: 0.0052
# Epoch 31/100
# 9/9 [==============================] - 1s 57ms/step - loss: 5.0168e-04 - val_loss: 0.0051
# Epoch 32/100
# 9/9 [==============================] - 1s 61ms/step - loss: 4.9224e-04 - val_loss: 0.0051
# Epoch 33/100
# 9/9 [==============================] - 0s 56ms/step - loss: 4.8562e-04 - val_loss: 0.0051
# Epoch 34/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.8166e-04 - val_loss: 0.0050
# Epoch 35/100
# 9/9 [==============================] - 1s 92ms/step - loss: 4.7756e-04 - val_loss: 0.0050
# Epoch 36/100
# 9/9 [==============================] - 1s 92ms/step - loss: 4.9275e-04 - val_loss: 0.0050
# Epoch 37/100
# 9/9 [==============================] - 1s 103ms/step - loss: 4.7732e-04 - val_loss: 0.0050
# Epoch 38/100
# 9/9 [==============================] - 1s 93ms/step - loss: 4.7926e-04 - val_loss: 0.0049
# Epoch 39/100
# 9/9 [==============================] - 1s 96ms/step - loss: 4.7192e-04 - val_loss: 0.0049
# Epoch 40/100
# 9/9 [==============================] - 1s 96ms/step - loss: 4.7384e-04 - val_loss: 0.0048
# Epoch 41/100
# 9/9 [==============================] - 1s 68ms/step - loss: 4.6824e-04 - val_loss: 0.0048
# Epoch 42/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.7466e-04 - val_loss: 0.0048
# Epoch 43/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.6919e-04 - val_loss: 0.0048
# Epoch 44/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.7201e-04 - val_loss: 0.0048
# Epoch 45/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.6614e-04 - val_loss: 0.0048
# Epoch 46/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.6900e-04 - val_loss: 0.0047
# Epoch 47/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.6992e-04 - val_loss: 0.0047
# Epoch 48/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.6876e-04 - val_loss: 0.0048
# Epoch 49/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.7041e-04 - val_loss: 0.0047
# Epoch 50/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.6409e-04 - val_loss: 0.0047
# Epoch 51/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6817e-04 - val_loss: 0.0047
# Epoch 52/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6636e-04 - val_loss: 0.0047
# Epoch 53/100
# 9/9 [==============================] - 0s 56ms/step - loss: 4.7255e-04 - val_loss: 0.0047
# Epoch 54/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6769e-04 - val_loss: 0.0046
# Epoch 55/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.7370e-04 - val_loss: 0.0047
# Epoch 56/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.6646e-04 - val_loss: 0.0047
# Epoch 57/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.7355e-04 - val_loss: 0.0047
# Epoch 58/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.7568e-04 - val_loss: 0.0047
# Epoch 59/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.7404e-04 - val_loss: 0.0047
# Epoch 60/100
# 9/9 [==============================] - 1s 78ms/step - loss: 4.7322e-04 - val_loss: 0.0047
# Epoch 61/100
# 9/9 [==============================] - 1s 93ms/step - loss: 4.6409e-04 - val_loss: 0.0047
# Epoch 62/100
# 9/9 [==============================] - 1s 90ms/step - loss: 4.8740e-04 - val_loss: 0.0047
# Epoch 63/100
# 9/9 [==============================] - 1s 90ms/step - loss: 4.7212e-04 - val_loss: 0.0047
# Epoch 64/100
# 9/9 [==============================] - 1s 106ms/step - loss: 4.7471e-04 - val_loss: 0.0047
# Epoch 65/100
# 9/9 [==============================] - 1s 106ms/step - loss: 4.9870e-04 - val_loss: 0.0047
# Epoch 66/100
# 9/9 [==============================] - 1s 81ms/step - loss: 4.9269e-04 - val_loss: 0.0046
# Epoch 67/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.7138e-04 - val_loss: 0.0046
# Epoch 68/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.6804e-04 - val_loss: 0.0046
# Epoch 69/100
# 9/9 [==============================] - 1s 56ms/step - loss: 4.7076e-04 - val_loss: 0.0046
# Epoch 70/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.7709e-04 - val_loss: 0.0047
# Epoch 71/100
# 9/9 [==============================] - 1s 56ms/step - loss: 4.6813e-04 - val_loss: 0.0047
# Epoch 72/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.8705e-04 - val_loss: 0.0047
# Epoch 73/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.8160e-04 - val_loss: 0.0047
# Epoch 74/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.8283e-04 - val_loss: 0.0047
# Epoch 75/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.7565e-04 - val_loss: 0.0046
# Epoch 76/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.6871e-04 - val_loss: 0.0046
# Epoch 77/100
# 9/9 [==============================] - 1s 56ms/step - loss: 4.7389e-04 - val_loss: 0.0046
# Epoch 78/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.7078e-04 - val_loss: 0.0046
# Epoch 79/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.7400e-04 - val_loss: 0.0046
# Epoch 80/100
# 9/9 [==============================] - 1s 60ms/step - loss: 4.7021e-04 - val_loss: 0.0046
# Epoch 81/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.6760e-04 - val_loss: 0.0047
# Epoch 82/100
# 9/9 [==============================] - 1s 62ms/step - loss: 4.6971e-04 - val_loss: 0.0047
# Epoch 83/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.8039e-04 - val_loss: 0.0046
# Epoch 84/100
# 9/9 [==============================] - 1s 61ms/step - loss: 4.7565e-04 - val_loss: 0.0047
# Epoch 85/100
# 9/9 [==============================] - 1s 81ms/step - loss: 4.8436e-04 - val_loss: 0.0047
# Epoch 86/100
# 9/9 [==============================] - 1s 97ms/step - loss: 4.7328e-04 - val_loss: 0.0046
# Epoch 87/100
# 9/9 [==============================] - 1s 92ms/step - loss: 4.6785e-04 - val_loss: 0.0047
# Epoch 88/100
# 9/9 [==============================] - 1s 98ms/step - loss: 4.8145e-04 - val_loss: 0.0047
# Epoch 89/100
# 9/9 [==============================] - 1s 101ms/step - loss: 4.8911e-04 - val_loss: 0.0046
# Epoch 90/100
# 9/9 [==============================] - 1s 101ms/step - loss: 4.8844e-04 - val_loss: 0.0046
# Epoch 91/100
# 9/9 [==============================] - 1s 67ms/step - loss: 4.7876e-04 - val_loss: 0.0046
# Epoch 92/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6911e-04 - val_loss: 0.0046
# Epoch 93/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.6498e-04 - val_loss: 0.0046
# Epoch 94/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6937e-04 - val_loss: 0.0046
# Epoch 95/100
# 9/9 [==============================] - 1s 57ms/step - loss: 4.8792e-04 - val_loss: 0.0046
# Epoch 96/100
# 9/9 [==============================] - 1s 59ms/step - loss: 4.6902e-04 - val_loss: 0.0046
# Epoch 97/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6775e-04 - val_loss: 0.0046
# Epoch 98/100
# 9/9 [==============================] - 1s 61ms/step - loss: 4.6398e-04 - val_loss: 0.0046
# Epoch 99/100
# 9/9 [==============================] - 1s 56ms/step - loss: 4.7694e-04 - val_loss: 0.0046
# Epoch 100/100
# 9/9 [==============================] - 1s 58ms/step - loss: 4.6494e-04 - val_loss: 0.0046
# 17/17 [==============================] - 1s 12ms/step
# 6/6 [==============================] - 0s 14ms/step

# %%
# 10. Generate future predictions
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# %%
# Predict for 30, 60, 90 days
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# %%
# Function to create and show plots
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(15, 8))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# Calculate MAE, RMSE, and MAPE for test predictions
mae = mean_absolute_error(y_test, test_predict)
rmse = np.sqrt(mean_squared_error(y_test, test_predict))
mape = mean_absolute_percentage_error(y_test, test_predict)

print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
# Out:
# MAE: 29.478451070065013
# RMSE: 45.67162260846215
# MAPE: 900.6929372476603
