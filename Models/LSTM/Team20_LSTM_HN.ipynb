# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# TRAIN:TEST = 7:3

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/HaNoi.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 13s 240ms/step - loss: 0.0075
# Epoch 2/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0054
# Epoch 3/100
# 30/30 [==============================] - 6s 196ms/step - loss: 0.0053
# Epoch 4/100
# 30/30 [==============================] - 6s 204ms/step - loss: 0.0052
# Epoch 5/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0052
# Epoch 6/100
# 30/30 [==============================] - 7s 234ms/step - loss: 0.0052
# Epoch 7/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0051
# Epoch 8/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0051
# Epoch 9/100
# 30/30 [==============================] - 7s 238ms/step - loss: 0.0050
# Epoch 10/100
# 30/30 [==============================] - 5s 161ms/step - loss: 0.0049
# Epoch 11/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.0048
# Epoch 12/100
# 30/30 [==============================] - 6s 213ms/step - loss: 0.0047
# Epoch 13/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.0046
# Epoch 14/100
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0045
# Epoch 15/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0044
# Epoch 16/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0044
# Epoch 17/100
# 30/30 [==============================] - 7s 232ms/step - loss: 0.0042
# Epoch 18/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0041
# Epoch 19/100
# 30/30 [==============================] - 6s 199ms/step - loss: 0.0040
# Epoch 20/100
# 30/30 [==============================] - 6s 203ms/step - loss: 0.0040
# Epoch 21/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0039
# Epoch 22/100
# 30/30 [==============================] - 7s 227ms/step - loss: 0.0038
# Epoch 23/100
# 30/30 [==============================] - 5s 166ms/step - loss: 0.0038
# Epoch 24/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0038
# Epoch 25/100
# 30/30 [==============================] - 7s 236ms/step - loss: 0.0038
# Epoch 26/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0038
# Epoch 27/100
# 30/30 [==============================] - 6s 189ms/step - loss: 0.0037
# Epoch 28/100
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0038
# Epoch 29/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0038
# Epoch 30/100
# 30/30 [==============================] - 7s 226ms/step - loss: 0.0037
# Epoch 31/100
# 30/30 [==============================] - 8s 270ms/step - loss: 0.0037
# Epoch 32/100
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0038
# Epoch 33/100
# 30/30 [==============================] - 6s 192ms/step - loss: 0.0038
# Epoch 34/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0037
# Epoch 35/100
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0037
# Epoch 36/100
# 30/30 [==============================] - 5s 166ms/step - loss: 0.0037
# Epoch 37/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.0038
# Epoch 38/100
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0037
# Epoch 39/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0038
# Epoch 40/100
# 30/30 [==============================] - 7s 221ms/step - loss: 0.0038
# Epoch 41/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.0037
# Epoch 42/100
# 30/30 [==============================] - 5s 161ms/step - loss: 0.0037
# Epoch 43/100
# 30/30 [==============================] - 7s 241ms/step - loss: 0.0037
# Epoch 44/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0037
# Epoch 45/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.0037
# Epoch 46/100
# 30/30 [==============================] - 7s 227ms/step - loss: 0.0036
# Epoch 47/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0037
# Epoch 48/100
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0036
# Epoch 49/100
# 30/30 [==============================] - 6s 190ms/step - loss: 0.0036
# Epoch 50/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0037
# Epoch 51/100
# 30/30 [==============================] - 7s 243ms/step - loss: 0.0036
# Epoch 52/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0037
# Epoch 53/100
# 30/30 [==============================] - 5s 166ms/step - loss: 0.0036
# Epoch 54/100
# 30/30 [==============================] - 7s 236ms/step - loss: 0.0036
# Epoch 55/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0036
# Epoch 56/100
# 30/30 [==============================] - 6s 200ms/step - loss: 0.0036
# Epoch 57/100
# 30/30 [==============================] - 6s 205ms/step - loss: 0.0036
# Epoch 58/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0036
# Epoch 59/100
# 30/30 [==============================] - 7s 234ms/step - loss: 0.0036
# Epoch 60/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0037
# Epoch 61/100
# 30/30 [==============================] - 5s 160ms/step - loss: 0.0037
# Epoch 62/100
# 30/30 [==============================] - 7s 244ms/step - loss: 0.0037
# Epoch 63/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0036
# Epoch 64/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.0036
# Epoch 65/100
# 30/30 [==============================] - 8s 250ms/step - loss: 0.0036
# Epoch 66/100
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0036
# Epoch 67/100
# 30/30 [==============================] - 7s 236ms/step - loss: 0.0036
# Epoch 68/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0036
# Epoch 69/100
# 30/30 [==============================] - 6s 191ms/step - loss: 0.0036
# Epoch 70/100
# 30/30 [==============================] - 6s 206ms/step - loss: 0.0036
# Epoch 71/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0036
# Epoch 72/100
# 30/30 [==============================] - 7s 231ms/step - loss: 0.0036
# Epoch 73/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0036
# Epoch 74/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0036
# Epoch 75/100
# 30/30 [==============================] - 7s 242ms/step - loss: 0.0036
# Epoch 76/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0036
# Epoch 77/100
# 30/30 [==============================] - 6s 186ms/step - loss: 0.0036
# Epoch 78/100
# 30/30 [==============================] - 7s 216ms/step - loss: 0.0036
# Epoch 79/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0036
# Epoch 80/100
# 30/30 [==============================] - 6s 213ms/step - loss: 0.0036
# Epoch 81/100
# 30/30 [==============================] - 6s 185ms/step - loss: 0.0036
# Epoch 82/100
# 30/30 [==============================] - 4s 148ms/step - loss: 0.0036
# Epoch 83/100
# 30/30 [==============================] - 6s 217ms/step - loss: 0.0036
# Epoch 84/100
# 30/30 [==============================] - 5s 168ms/step - loss: 0.0036
# Epoch 85/100
# 30/30 [==============================] - 5s 162ms/step - loss: 0.0036
# Epoch 86/100
# 30/30 [==============================] - 7s 233ms/step - loss: 0.0036
# Epoch 87/100
# 30/30 [==============================] - 5s 159ms/step - loss: 0.0035
# Epoch 88/100
# 30/30 [==============================] - 5s 181ms/step - loss: 0.0036
# Epoch 89/100
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0036
# Epoch 90/100
# 30/30 [==============================] - 5s 159ms/step - loss: 0.0035
# Epoch 91/100
# 30/30 [==============================] - 6s 208ms/step - loss: 0.0035
# Epoch 92/100
# 30/30 [==============================] - 6s 182ms/step - loss: 0.0035
# Epoch 93/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0036
# Epoch 94/100
# 30/30 [==============================] - 7s 236ms/step - loss: 0.0036
# Epoch 95/100
# 30/30 [==============================] - 5s 163ms/step - loss: 0.0036
# Epoch 96/100
# 30/30 [==============================] - 5s 161ms/step - loss: 0.0036
# Epoch 97/100
# 30/30 [==============================] - 7s 233ms/step - loss: 0.0036
# Epoch 98/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0035
# Epoch 99/100
# 30/30 [==============================] - 5s 184ms/step - loss: 0.0036
# Epoch 100/100
# 30/30 [==============================] - 6s 212ms/step - loss: 0.0036
# 59/59 [==============================] - 4s 49ms/step
# 24/24 [==============================] - 1s 59ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 26.611587140532002
# MAE: 19.821723455436697
# MAPE: 0.31680521245000515

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %% [markdown]
# TRAIN:TEST = 8:2

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/HaNoi.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 34/34 [==============================] - 13s 226ms/step - loss: 0.0070
# Epoch 2/100
# 34/34 [==============================] - 6s 159ms/step - loss: 0.0052
# Epoch 3/100
# 34/34 [==============================] - 6s 170ms/step - loss: 0.0051
# Epoch 4/100
# 34/34 [==============================] - 7s 219ms/step - loss: 0.0051
# Epoch 5/100
# 34/34 [==============================] - 6s 171ms/step - loss: 0.0049
# Epoch 6/100
# 34/34 [==============================] - 8s 229ms/step - loss: 0.0049
# Epoch 7/100
# 34/34 [==============================] - 6s 166ms/step - loss: 0.0047
# Epoch 8/100
# 34/34 [==============================] - 7s 194ms/step - loss: 0.0046
# Epoch 9/100
# 34/34 [==============================] - 6s 174ms/step - loss: 0.0045
# Epoch 10/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0044
# Epoch 11/100
# 34/34 [==============================] - 7s 220ms/step - loss: 0.0043
# Epoch 12/100
# 34/34 [==============================] - 5s 157ms/step - loss: 0.0042
# Epoch 13/100
# 34/34 [==============================] - 8s 228ms/step - loss: 0.0041
# Epoch 14/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0040
# Epoch 15/100
# 34/34 [==============================] - 6s 179ms/step - loss: 0.0039
# Epoch 16/100
# 34/34 [==============================] - 7s 212ms/step - loss: 0.0038
# Epoch 17/100
# 34/34 [==============================] - 6s 162ms/step - loss: 0.0038
# Epoch 18/100
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0037
# Epoch 19/100
# 34/34 [==============================] - 6s 162ms/step - loss: 0.0037
# Epoch 20/100
# 34/34 [==============================] - 7s 201ms/step - loss: 0.0037
# Epoch 21/100
# 34/34 [==============================] - 6s 187ms/step - loss: 0.0037
# Epoch 22/100
# 34/34 [==============================] - 6s 173ms/step - loss: 0.0036
# Epoch 23/100
# 34/34 [==============================] - 7s 209ms/step - loss: 0.0036
# Epoch 24/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0037
# Epoch 25/100
# 34/34 [==============================] - 8s 223ms/step - loss: 0.0036
# Epoch 26/100
# 34/34 [==============================] - 5s 162ms/step - loss: 0.0036
# Epoch 27/100
# 34/34 [==============================] - 6s 189ms/step - loss: 0.0036
# Epoch 28/100
# 34/34 [==============================] - 9s 259ms/step - loss: 0.0036
# Epoch 29/100
# 34/34 [==============================] - 5s 159ms/step - loss: 0.0036
# Epoch 30/100
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0036
# Epoch 31/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0037
# Epoch 32/100
# 34/34 [==============================] - 7s 222ms/step - loss: 0.0036
# Epoch 33/100
# 34/34 [==============================] - 6s 169ms/step - loss: 0.0036
# Epoch 34/100
# 34/34 [==============================] - 6s 180ms/step - loss: 0.0036
# Epoch 35/100
# 34/34 [==============================] - 7s 215ms/step - loss: 0.0036
# Epoch 36/100
# 34/34 [==============================] - 6s 166ms/step - loss: 0.0036
# Epoch 37/100
# 34/34 [==============================] - 8s 225ms/step - loss: 0.0036
# Epoch 38/100
# 34/34 [==============================] - 6s 164ms/step - loss: 0.0035
# Epoch 39/100
# 34/34 [==============================] - 7s 213ms/step - loss: 0.0036
# Epoch 40/100
# 34/34 [==============================] - 6s 173ms/step - loss: 0.0035
# Epoch 41/100
# 34/34 [==============================] - 5s 153ms/step - loss: 0.0035
# Epoch 42/100
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0036
# Epoch 43/100
# 34/34 [==============================] - 6s 164ms/step - loss: 0.0035
# Epoch 44/100
# 34/34 [==============================] - 8s 231ms/step - loss: 0.0035
# Epoch 45/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0036
# Epoch 46/100
# 34/34 [==============================] - 7s 195ms/step - loss: 0.0036
# Epoch 47/100
# 34/34 [==============================] - 7s 188ms/step - loss: 0.0035
# Epoch 48/100
# 34/34 [==============================] - 6s 162ms/step - loss: 0.0035
# Epoch 49/100
# 34/34 [==============================] - 8s 227ms/step - loss: 0.0035
# Epoch 50/100
# 34/34 [==============================] - 5s 156ms/step - loss: 0.0036
# Epoch 51/100
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0035
# Epoch 52/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0035
# Epoch 53/100
# 34/34 [==============================] - 6s 185ms/step - loss: 0.0035
# Epoch 54/100
# 34/34 [==============================] - 7s 208ms/step - loss: 0.0035
# Epoch 55/100
# 34/34 [==============================] - 5s 160ms/step - loss: 0.0035
# Epoch 56/100
# 34/34 [==============================] - 8s 233ms/step - loss: 0.0035
# Epoch 57/100
# 34/34 [==============================] - 5s 162ms/step - loss: 0.0036
# Epoch 58/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.0035
# Epoch 59/100
# 34/34 [==============================] - 7s 205ms/step - loss: 0.0035
# Epoch 60/100
# 34/34 [==============================] - 8s 248ms/step - loss: 0.0035
# Epoch 61/100
# 34/34 [==============================] - 6s 172ms/step - loss: 0.0035
# Epoch 62/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0035
# Epoch 63/100
# 34/34 [==============================] - 7s 212ms/step - loss: 0.0035
# Epoch 64/100
# 34/34 [==============================] - 5s 158ms/step - loss: 0.0035
# Epoch 65/100
# 34/34 [==============================] - 8s 230ms/step - loss: 0.0035
# Epoch 66/100
# 34/34 [==============================] - 6s 166ms/step - loss: 0.0035
# Epoch 67/100
# 34/34 [==============================] - 7s 206ms/step - loss: 0.0035
# Epoch 68/100
# 34/34 [==============================] - 6s 184ms/step - loss: 0.0035
# Epoch 69/100
# 34/34 [==============================] - 6s 168ms/step - loss: 0.0035
# Epoch 70/100
# 34/34 [==============================] - 8s 232ms/step - loss: 0.0035
# Epoch 71/100
# 34/34 [==============================] - 5s 156ms/step - loss: 0.0035
# Epoch 72/100
# 34/34 [==============================] - 8s 230ms/step - loss: 0.0035
# Epoch 73/100
# 34/34 [==============================] - 6s 162ms/step - loss: 0.0035
# Epoch 74/100
# 34/34 [==============================] - 6s 178ms/step - loss: 0.0035
# Epoch 75/100
# 34/34 [==============================] - 7s 207ms/step - loss: 0.0035
# Epoch 76/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0035
# Epoch 77/100
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0035
# Epoch 78/100
# 34/34 [==============================] - 5s 161ms/step - loss: 0.0035
# Epoch 79/100
# 34/34 [==============================] - 7s 202ms/step - loss: 0.0035
# Epoch 80/100
# 34/34 [==============================] - 6s 180ms/step - loss: 0.0035
# Epoch 81/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0035
# Epoch 82/100
# 34/34 [==============================] - 7s 216ms/step - loss: 0.0035
# Epoch 83/100
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0035
# Epoch 84/100
# 34/34 [==============================] - 7s 221ms/step - loss: 0.0035
# Epoch 85/100
# 34/34 [==============================] - 6s 161ms/step - loss: 0.0035
# Epoch 86/100
# 34/34 [==============================] - 6s 173ms/step - loss: 0.0035
# Epoch 87/100
# 34/34 [==============================] - 7s 213ms/step - loss: 0.0035
# Epoch 88/100
# 34/34 [==============================] - 5s 159ms/step - loss: 0.0035
# Epoch 89/100
# 34/34 [==============================] - 8s 229ms/step - loss: 0.0034
# Epoch 90/100
# 34/34 [==============================] - 5s 161ms/step - loss: 0.0035
# Epoch 91/100
# 34/34 [==============================] - 7s 213ms/step - loss: 0.0034
# Epoch 92/100
# 34/34 [==============================] - 8s 235ms/step - loss: 0.0034
# Epoch 93/100
# 34/34 [==============================] - 5s 162ms/step - loss: 0.0035
# Epoch 94/100
# 34/34 [==============================] - 8s 231ms/step - loss: 0.0035
# Epoch 95/100
# 34/34 [==============================] - 6s 165ms/step - loss: 0.0035
# Epoch 96/100
# 34/34 [==============================] - 8s 229ms/step - loss: 0.0035
# Epoch 97/100
# 34/34 [==============================] - 6s 161ms/step - loss: 0.0035
# Epoch 98/100
# 34/34 [==============================] - 6s 183ms/step - loss: 0.0035
# Epoch 99/100
# 34/34 [==============================] - 7s 196ms/step - loss: 0.0035
# Epoch 100/100
# 34/34 [==============================] - 6s 164ms/step - loss: 0.0034
# 68/68 [==============================] - 4s 36ms/step
# 15/15 [==============================] - 1s 51ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 28.03310667906713
# MAE: 20.878747895136634
# MAPE: 0.24738765459587256

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %% [markdown]
# TRAIN:TEST = 9:1

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/HaNoi.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 39/39 [==============================] - 15s 215ms/step - loss: 0.0073
# Epoch 2/100
# 39/39 [==============================] - 6s 158ms/step - loss: 0.0053
# Epoch 3/100
# 39/39 [==============================] - 8s 210ms/step - loss: 0.0051
# Epoch 4/100
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0050
# Epoch 5/100
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0050
# Epoch 6/100
# 39/39 [==============================] - 6s 159ms/step - loss: 0.0049
# Epoch 7/100
# 39/39 [==============================] - 9s 223ms/step - loss: 0.0047
# Epoch 8/100
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0047
# Epoch 9/100
# 39/39 [==============================] - 9s 224ms/step - loss: 0.0045
# Epoch 10/100
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0045
# Epoch 11/100
# 39/39 [==============================] - 9s 227ms/step - loss: 0.0043
# Epoch 12/100
# 39/39 [==============================] - 8s 194ms/step - loss: 0.0042
# Epoch 13/100
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0040
# Epoch 14/100
# 39/39 [==============================] - 6s 159ms/step - loss: 0.0039
# Epoch 15/100
# 39/39 [==============================] - 9s 224ms/step - loss: 0.0038
# Epoch 16/100
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0038
# Epoch 17/100
# 39/39 [==============================] - 8s 207ms/step - loss: 0.0037
# Epoch 18/100
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0037
# Epoch 19/100
# 39/39 [==============================] - 8s 213ms/step - loss: 0.0038
# Epoch 20/100
# 39/39 [==============================] - 7s 168ms/step - loss: 0.0038
# Epoch 21/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0038
# Epoch 22/100
# 39/39 [==============================] - 7s 170ms/step - loss: 0.0037
# Epoch 23/100
# 39/39 [==============================] - 7s 191ms/step - loss: 0.0037
# Epoch 24/100
# 39/39 [==============================] - 7s 187ms/step - loss: 0.0037
# Epoch 25/100
# 39/39 [==============================] - 7s 184ms/step - loss: 0.0036
# Epoch 26/100
# 39/39 [==============================] - 8s 197ms/step - loss: 0.0037
# Epoch 27/100
# 39/39 [==============================] - 6s 167ms/step - loss: 0.0037
# Epoch 28/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0036
# Epoch 29/100
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0036
# Epoch 30/100
# 39/39 [==============================] - 8s 210ms/step - loss: 0.0036
# Epoch 31/100
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0036
# Epoch 32/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0037
# Epoch 33/100
# 39/39 [==============================] - 6s 158ms/step - loss: 0.0037
# Epoch 34/100
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0037
# Epoch 35/100
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0037
# Epoch 36/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0036
# Epoch 37/100
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0036
# Epoch 38/100
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0036
# Epoch 39/100
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0036
# Epoch 40/100
# 39/39 [==============================] - 9s 229ms/step - loss: 0.0036
# Epoch 41/100
# 39/39 [==============================] - 8s 197ms/step - loss: 0.0036
# Epoch 42/100
# 39/39 [==============================] - 8s 213ms/step - loss: 0.0036
# Epoch 43/100
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0036
# Epoch 44/100
# 39/39 [==============================] - 8s 218ms/step - loss: 0.0036
# Epoch 45/100
# 39/39 [==============================] - 6s 156ms/step - loss: 0.0036
# Epoch 46/100
# 39/39 [==============================] - 8s 218ms/step - loss: 0.0036
# Epoch 47/100
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0036
# Epoch 48/100
# 39/39 [==============================] - 8s 219ms/step - loss: 0.0036
# Epoch 49/100
# 39/39 [==============================] - 6s 153ms/step - loss: 0.0036
# Epoch 50/100
# 39/39 [==============================] - 9s 219ms/step - loss: 0.0036
# Epoch 51/100
# 39/39 [==============================] - 6s 159ms/step - loss: 0.0036
# Epoch 52/100
# 39/39 [==============================] - 8s 205ms/step - loss: 0.0036
# Epoch 53/100
# 39/39 [==============================] - 7s 165ms/step - loss: 0.0036
# Epoch 54/100
# 39/39 [==============================] - 8s 204ms/step - loss: 0.0036
# Epoch 55/100
# 39/39 [==============================] - 7s 188ms/step - loss: 0.0036
# Epoch 56/100
# 39/39 [==============================] - 7s 184ms/step - loss: 0.0035
# Epoch 57/100
# 39/39 [==============================] - 7s 185ms/step - loss: 0.0036
# Epoch 58/100
# 39/39 [==============================] - 7s 168ms/step - loss: 0.0036
# Epoch 59/100
# 39/39 [==============================] - 7s 189ms/step - loss: 0.0035
# Epoch 60/100
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0036
# Epoch 61/100
# 39/39 [==============================] - 8s 198ms/step - loss: 0.0036
# Epoch 62/100
# 39/39 [==============================] - 6s 149ms/step - loss: 0.0036
# Epoch 63/100
# 39/39 [==============================] - 8s 219ms/step - loss: 0.0036
# Epoch 64/100
# 39/39 [==============================] - 6s 154ms/step - loss: 0.0036
# Epoch 65/100
# 39/39 [==============================] - 8s 215ms/step - loss: 0.0035
# Epoch 66/100
# 39/39 [==============================] - 6s 158ms/step - loss: 0.0035
# Epoch 67/100
# 39/39 [==============================] - 8s 197ms/step - loss: 0.0035
# Epoch 68/100
# 39/39 [==============================] - 6s 156ms/step - loss: 0.0035
# Epoch 69/100
# 39/39 [==============================] - 8s 203ms/step - loss: 0.0035
# Epoch 70/100
# 39/39 [==============================] - 8s 212ms/step - loss: 0.0035
# Epoch 71/100
# 39/39 [==============================] - 6s 151ms/step - loss: 0.0035
# Epoch 72/100
# 39/39 [==============================] - 8s 212ms/step - loss: 0.0036
# Epoch 73/100
# 39/39 [==============================] - 6s 156ms/step - loss: 0.0035
# Epoch 74/100
# 39/39 [==============================] - 8s 204ms/step - loss: 0.0035
# Epoch 75/100
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0035
# Epoch 76/100
# 39/39 [==============================] - 9s 223ms/step - loss: 0.0035
# Epoch 77/100
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0035
# Epoch 78/100
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0036
# Epoch 79/100
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0035
# Epoch 80/100
# 39/39 [==============================] - 8s 216ms/step - loss: 0.0035
# Epoch 81/100
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0035
# Epoch 82/100
# 39/39 [==============================] - 8s 200ms/step - loss: 0.0035
# Epoch 83/100
# 39/39 [==============================] - 7s 178ms/step - loss: 0.0035
# Epoch 84/100
# 39/39 [==============================] - 7s 191ms/step - loss: 0.0035
# Epoch 85/100
# 39/39 [==============================] - 7s 173ms/step - loss: 0.0035
# Epoch 86/100
# 39/39 [==============================] - 7s 187ms/step - loss: 0.0035
# Epoch 87/100
# 39/39 [==============================] - 8s 192ms/step - loss: 0.0035
# Epoch 88/100
# 39/39 [==============================] - 7s 178ms/step - loss: 0.0035
# Epoch 89/100
# 39/39 [==============================] - 7s 189ms/step - loss: 0.0035
# Epoch 90/100
# 39/39 [==============================] - 7s 180ms/step - loss: 0.0035
# Epoch 91/100
# 39/39 [==============================] - 8s 204ms/step - loss: 0.0035
# Epoch 92/100
# 39/39 [==============================] - 7s 176ms/step - loss: 0.0035
# Epoch 93/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0035
# Epoch 94/100
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0035
# Epoch 95/100
# 39/39 [==============================] - 8s 209ms/step - loss: 0.0035
# Epoch 96/100
# 39/39 [==============================] - 6s 150ms/step - loss: 0.0035
# Epoch 97/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.0035
# Epoch 98/100
# 39/39 [==============================] - 8s 206ms/step - loss: 0.0035
# Epoch 99/100
# 39/39 [==============================] - 8s 195ms/step - loss: 0.0035
# Epoch 100/100
# 39/39 [==============================] - 7s 172ms/step - loss: 0.0035
# 77/77 [==============================] - 4s 38ms/step
# 6/6 [==============================] - 0s 39ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 25.259315226643558
# MAE: 19.30490085205745
# MAPE: 0.26835987566090097

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')
