# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/BacNinh.csv')
df1=df.reset_index()['AQI']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 12s 339ms/step - loss: 0.0466 - val_loss: 0.0294
# Epoch 2/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0247 - val_loss: 0.0302
# Epoch 3/100
# 12/12 [==============================] - 3s 246ms/step - loss: 0.0228 - val_loss: 0.0286
# Epoch 4/100
# 12/12 [==============================] - 4s 359ms/step - loss: 0.0219 - val_loss: 0.0277
# Epoch 5/100
# 12/12 [==============================] - 4s 314ms/step - loss: 0.0214 - val_loss: 0.0275
# Epoch 6/100
# 12/12 [==============================] - 3s 206ms/step - loss: 0.0213 - val_loss: 0.0276
# Epoch 7/100
# 12/12 [==============================] - 2s 197ms/step - loss: 0.0214 - val_loss: 0.0274
# Epoch 8/100
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0217 - val_loss: 0.0278
# Epoch 9/100
# 12/12 [==============================] - 3s 276ms/step - loss: 0.0215 - val_loss: 0.0273
# Epoch 10/100
# 12/12 [==============================] - 4s 311ms/step - loss: 0.0210 - val_loss: 0.0273
# Epoch 11/100
# 12/12 [==============================] - 2s 201ms/step - loss: 0.0209 - val_loss: 0.0272
# Epoch 12/100
# 12/12 [==============================] - 2s 204ms/step - loss: 0.0211 - val_loss: 0.0272
# Epoch 13/100
# 12/12 [==============================] - 2s 195ms/step - loss: 0.0208 - val_loss: 0.0267
# Epoch 14/100
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0207 - val_loss: 0.0268
# Epoch 15/100
# 12/12 [==============================] - 4s 302ms/step - loss: 0.0209 - val_loss: 0.0269
# Epoch 16/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.0210 - val_loss: 0.0270
# Epoch 17/100
# 12/12 [==============================] - 2s 191ms/step - loss: 0.0204 - val_loss: 0.0262
# Epoch 18/100
# 12/12 [==============================] - 2s 196ms/step - loss: 0.0204 - val_loss: 0.0272
# Epoch 19/100
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0215 - val_loss: 0.0258
# Epoch 20/100
# 12/12 [==============================] - 2s 192ms/step - loss: 0.0206 - val_loss: 0.0261
# Epoch 21/100
# 12/12 [==============================] - 4s 342ms/step - loss: 0.0201 - val_loss: 0.0254
# Epoch 22/100
# 12/12 [==============================] - 3s 249ms/step - loss: 0.0200 - val_loss: 0.0256
# Epoch 23/100
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0201 - val_loss: 0.0255
# Epoch 24/100
# 12/12 [==============================] - 3s 229ms/step - loss: 0.0198 - val_loss: 0.0248
# Epoch 25/100
# 12/12 [==============================] - 2s 195ms/step - loss: 0.0195 - val_loss: 0.0245
# Epoch 26/100
# 12/12 [==============================] - 3s 294ms/step - loss: 0.0191 - val_loss: 0.0242
# Epoch 27/100
# 12/12 [==============================] - 3s 249ms/step - loss: 0.0188 - val_loss: 0.0239
# Epoch 28/100
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0187 - val_loss: 0.0234
# Epoch 29/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0185 - val_loss: 0.0230
# Epoch 30/100
# 12/12 [==============================] - 3s 242ms/step - loss: 0.0175 - val_loss: 0.0224
# Epoch 31/100
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0168 - val_loss: 0.0216
# Epoch 32/100
# 12/12 [==============================] - 4s 306ms/step - loss: 0.0159 - val_loss: 0.0206
# Epoch 33/100
# 12/12 [==============================] - 3s 207ms/step - loss: 0.0147 - val_loss: 0.0196
# Epoch 34/100
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0139 - val_loss: 0.0220
# Epoch 35/100
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0134 - val_loss: 0.0186
# Epoch 36/100
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0122 - val_loss: 0.0180
# Epoch 37/100
# 12/12 [==============================] - 3s 240ms/step - loss: 0.0114 - val_loss: 0.0197
# Epoch 38/100
# 12/12 [==============================] - 4s 325ms/step - loss: 0.0122 - val_loss: 0.0179
# Epoch 39/100
# 12/12 [==============================] - 2s 183ms/step - loss: 0.0112 - val_loss: 0.0179
# Epoch 40/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0107 - val_loss: 0.0186
# Epoch 41/100
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0104 - val_loss: 0.0185
# Epoch 42/100
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0105 - val_loss: 0.0187
# Epoch 43/100
# 12/12 [==============================] - 3s 233ms/step - loss: 0.0106 - val_loss: 0.0182
# Epoch 44/100
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0105 - val_loss: 0.0183
# Epoch 45/100
# 12/12 [==============================] - 2s 196ms/step - loss: 0.0109 - val_loss: 0.0179
# Epoch 46/100
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0104 - val_loss: 0.0179
# Epoch 47/100
# 12/12 [==============================] - 2s 192ms/step - loss: 0.0106 - val_loss: 0.0179
# Epoch 48/100
# 12/12 [==============================] - 2s 196ms/step - loss: 0.0105 - val_loss: 0.0186
# Epoch 49/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.0114 - val_loss: 0.0191
# Epoch 50/100
# 12/12 [==============================] - 3s 278ms/step - loss: 0.0109 - val_loss: 0.0178
# Epoch 51/100
# 12/12 [==============================] - 2s 182ms/step - loss: 0.0105 - val_loss: 0.0177
# Epoch 52/100
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0103 - val_loss: 0.0180
# Epoch 53/100
# 12/12 [==============================] - 2s 182ms/step - loss: 0.0103 - val_loss: 0.0177
# Epoch 54/100
# 12/12 [==============================] - 2s 183ms/step - loss: 0.0102 - val_loss: 0.0176
# Epoch 55/100
# 12/12 [==============================] - 3s 287ms/step - loss: 0.0101 - val_loss: 0.0184
# Epoch 56/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.0110 - val_loss: 0.0181
# Epoch 57/100
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0106 - val_loss: 0.0176
# Epoch 58/100
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0105 - val_loss: 0.0176
# Epoch 59/100
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0102 - val_loss: 0.0178
# Epoch 60/100
# 12/12 [==============================] - 2s 193ms/step - loss: 0.0105 - val_loss: 0.0176
# Epoch 61/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.0101 - val_loss: 0.0176
# Epoch 62/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.0102 - val_loss: 0.0175
# Epoch 63/100
# 12/12 [==============================] - 3s 246ms/step - loss: 0.0102 - val_loss: 0.0175
# Epoch 64/100
# 12/12 [==============================] - 4s 303ms/step - loss: 0.0101 - val_loss: 0.0177
# Epoch 65/100
# 12/12 [==============================] - 2s 198ms/step - loss: 0.0101 - val_loss: 0.0174
# Epoch 66/100
# 12/12 [==============================] - 4s 316ms/step - loss: 0.0109 - val_loss: 0.0180
# Epoch 67/100
# 12/12 [==============================] - 3s 267ms/step - loss: 0.0103 - val_loss: 0.0186
# Epoch 68/100
# 12/12 [==============================] - 2s 188ms/step - loss: 0.0116 - val_loss: 0.0187
# Epoch 69/100
# 12/12 [==============================] - 3s 240ms/step - loss: 0.0112 - val_loss: 0.0187
# Epoch 70/100
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0107 - val_loss: 0.0175
# Epoch 71/100
# 12/12 [==============================] - 3s 225ms/step - loss: 0.0102 - val_loss: 0.0182
# Epoch 72/100
# 12/12 [==============================] - 4s 328ms/step - loss: 0.0104 - val_loss: 0.0176
# Epoch 73/100
# 12/12 [==============================] - 2s 191ms/step - loss: 0.0101 - val_loss: 0.0175
# Epoch 74/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0102 - val_loss: 0.0176
# Epoch 75/100
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0103 - val_loss: 0.0172
# Epoch 76/100
# 12/12 [==============================] - 2s 180ms/step - loss: 0.0102 - val_loss: 0.0174
# Epoch 77/100
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0101 - val_loss: 0.0175
# Epoch 78/100
# 12/12 [==============================] - 4s 333ms/step - loss: 0.0100 - val_loss: 0.0176
# Epoch 79/100
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0101 - val_loss: 0.0174
# Epoch 80/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0102 - val_loss: 0.0171
# Epoch 81/100
# 12/12 [==============================] - 2s 188ms/step - loss: 0.0099 - val_loss: 0.0178
# Epoch 82/100
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0103 - val_loss: 0.0172
# Epoch 83/100
# 12/12 [==============================] - 3s 259ms/step - loss: 0.0102 - val_loss: 0.0172
# Epoch 84/100
# 12/12 [==============================] - 4s 304ms/step - loss: 0.0103 - val_loss: 0.0173
# Epoch 85/100
# 12/12 [==============================] - 2s 192ms/step - loss: 0.0101 - val_loss: 0.0175
# Epoch 86/100
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0103 - val_loss: 0.0172
# Epoch 87/100
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0101 - val_loss: 0.0174
# Epoch 88/100
# 12/12 [==============================] - 3s 232ms/step - loss: 0.0103 - val_loss: 0.0180
# Epoch 89/100
# 12/12 [==============================] - 5s 445ms/step - loss: 0.0101 - val_loss: 0.0173
# Epoch 90/100
# 12/12 [==============================] - 3s 263ms/step - loss: 0.0108 - val_loss: 0.0170
# Epoch 91/100
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0102 - val_loss: 0.0178
# Epoch 92/100
# 12/12 [==============================] - 2s 191ms/step - loss: 0.0102 - val_loss: 0.0175
# Epoch 93/100
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0102 - val_loss: 0.0173
# Epoch 94/100
# 12/12 [==============================] - 2s 191ms/step - loss: 0.0101 - val_loss: 0.0171
# Epoch 95/100
# 12/12 [==============================] - 4s 295ms/step - loss: 0.0100 - val_loss: 0.0172
# Epoch 96/100
# 12/12 [==============================] - 3s 237ms/step - loss: 0.0101 - val_loss: 0.0180
# Epoch 97/100
# 12/12 [==============================] - 2s 183ms/step - loss: 0.0105 - val_loss: 0.0189
# Epoch 98/100
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0104 - val_loss: 0.0173
# Epoch 99/100
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0102 - val_loss: 0.0173
# Epoch 100/100
# 12/12 [==============================] - 2s 200ms/step - loss: 0.0101 - val_loss: 0.0174

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 23/23 [==============================] - 3s 61ms/step
# 8/8 [==============================] - 1s 66ms/step

# %%
# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest , test_predict))
mae = mean_absolute_error(ytest , test_predict)
mape = mean_absolute_percentage_error(ytest , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 103.7903182902957
# MAE: 95.65142634016163
# MAPE: 379.89621822043165

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# %%
# Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# %%
# Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')
