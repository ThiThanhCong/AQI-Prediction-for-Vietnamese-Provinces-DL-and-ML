# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# TRAIN:TEST = 7:3

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 11s 197ms/step - loss: 0.0022
# Epoch 2/100
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0017
# Epoch 3/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0017
# Epoch 4/100
# 25/25 [==============================] - 4s 159ms/step - loss: 0.0016
# Epoch 5/100
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0016
# Epoch 6/100
# 25/25 [==============================] - 4s 140ms/step - loss: 0.0017
# Epoch 7/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0015
# Epoch 8/100
# 25/25 [==============================] - 5s 190ms/step - loss: 0.0015
# Epoch 9/100
# 25/25 [==============================] - 5s 178ms/step - loss: 0.0015
# Epoch 10/100
# 25/25 [==============================] - 4s 141ms/step - loss: 0.0015
# Epoch 11/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0014
# Epoch 12/100
# 25/25 [==============================] - 5s 218ms/step - loss: 0.0015
# Epoch 13/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0014
# Epoch 14/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0014
# Epoch 15/100
# 25/25 [==============================] - 4s 157ms/step - loss: 0.0014
# Epoch 16/100
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0014
# Epoch 17/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0014
# Epoch 18/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0014
# Epoch 19/100
# 25/25 [==============================] - 5s 191ms/step - loss: 0.0014
# Epoch 20/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0014
# Epoch 21/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0013
# Epoch 22/100
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0013
# Epoch 23/100
# 25/25 [==============================] - 6s 228ms/step - loss: 0.0013
# Epoch 24/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0013
# Epoch 25/100
# 25/25 [==============================] - 4s 144ms/step - loss: 0.0013
# Epoch 26/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0013
# Epoch 27/100
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0013
# Epoch 28/100
# 25/25 [==============================] - 4s 143ms/step - loss: 0.0013
# Epoch 29/100
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0013
# Epoch 30/100
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0013
# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 22.593217919517187
# MAE: 12.78078827296521
# MAPE: 0.2708796102671602

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(20, 5))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %%
# Dự đoán chỉ số AQI theo 30. 60 và 90 ngày
for days in [30, 60, 90]:
    future_days = predict_future(model, df1, time_step, days)
    plt.figure(figsize=(20, 5))
    plt.plot(range(1, days + 1), future_days, label=f'Predicted AQI for {days} days', linestyle='--')
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.legend()
    plt.show()

# %% [markdown]
# TRAIN:TEST = 8:2

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 28/28 [==============================] - 12s 210ms/step - loss: 0.0023
# Epoch 2/100
# 28/28 [==============================] - 4s 151ms/step - loss: 0.0016
# Epoch 3/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0016
# Epoch 4/100
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0016
# Epoch 5/100
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0016
# Epoch 6/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0015
# Epoch 7/100
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0015
# Epoch 8/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0015
# Epoch 9/100
# 28/28 [==============================] - 4s 149ms/step - loss: 0.0015
# Epoch 10/100
# 28/28 [==============================] - 6s 217ms/step - loss: 0.0014
# Epoch 11/100
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0014
# Epoch 12/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0014
# Epoch 13/100
# 28/28 [==============================] - 6s 204ms/step - loss: 0.0014
# Epoch 14/100
# 28/28 [==============================] - 5s 161ms/step - loss: 0.0014
# Epoch 15/100
# 28/28 [==============================] - 4s 149ms/step - loss: 0.0014
# Epoch 16/100
# 28/28 [==============================] - 5s 192ms/step - loss: 0.0013
# Epoch 17/100
# 28/28 [==============================] - 5s 177ms/step - loss: 0.0013
# Epoch 18/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0013
# Epoch 19/100
# 28/28 [==============================] - 5s 176ms/step - loss: 0.0013
# Epoch 20/100
# 28/28 [==============================] - 5s 189ms/step - loss: 0.0013
# Epoch 21/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0013
# Epoch 22/100
# 28/28 [==============================] - 5s 163ms/step - loss: 0.0013
# Epoch 23/100
# 28/28 [==============================] - 6s 202ms/step - loss: 0.0013
# Epoch 24/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0013
# Epoch 25/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0013
# Epoch 26/100
# 28/28 [==============================] - 6s 217ms/step - loss: 0.0013
# Epoch 27/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0013
# Epoch 28/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0013
# Epoch 29/100
# 28/28 [==============================] - 6s 223ms/step - loss: 0.0012
# Epoch 30/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0012
# Epoch 31/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0012
# Epoch 32/100
# 28/28 [==============================] - 6s 217ms/step - loss: 0.0012
# Epoch 33/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0013
# Epoch 34/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0012
# Epoch 35/100
# 28/28 [==============================] - 6s 207ms/step - loss: 0.0012
# Epoch 36/100
# 28/28 [==============================] - 4s 153ms/step - loss: 0.0012
# Epoch 37/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0012
# Epoch 38/100
# 28/28 [==============================] - 5s 194ms/step - loss: 0.0012
# Epoch 39/100
# 28/28 [==============================] - 5s 170ms/step - loss: 0.0013
# Epoch 40/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0012
# Epoch 41/100
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0013
# Epoch 42/100
# 28/28 [==============================] - 5s 185ms/step - loss: 0.0012
# Epoch 43/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0012
# Epoch 81/100
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0012
# Epoch 82/100
# 28/28 [==============================] - 6s 211ms/step - loss: 0.0012
# Epoch 83/100
# 28/28 [==============================] - 4s 152ms/step - loss: 0.0012
# Epoch 84/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0011
# Epoch 85/100
# 28/28 [==============================] - 6s 200ms/step - loss: 0.0012
# Epoch 86/100
# 28/28 [==============================] - 5s 169ms/step - loss: 0.0012
# Epoch 87/100
# 28/28 [==============================] - 4s 149ms/step - loss: 0.0012
# Epoch 88/100
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0012
# Epoch 89/100
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0012
# Epoch 90/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0011
# Epoch 91/100
# 28/28 [==============================] - 5s 171ms/step - loss: 0.0011
# Epoch 92/100
# 28/28 [==============================] - 6s 197ms/step - loss: 0.0012
# Epoch 93/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0011
# Epoch 94/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012
# Epoch 95/100
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0012
# Epoch 96/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0012
# Epoch 97/100
# 28/28 [==============================] - 4s 152ms/step - loss: 0.0011
# Epoch 98/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.0011
# Epoch 99/100
# 28/28 [==============================] - 5s 185ms/step - loss: 0.0012
# Epoch 100/100
# 28/28 [==============================] - 4s 151ms/step - loss: 0.0011
# 56/56 [==============================] - 3s 35ms/step
# 12/12 [==============================] - 0s 35ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 15.859498087797858
# MAE: 10.356214134589486
# MAPE: 0.2136494061197183

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(20, 5))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %%
# Dự đoán chỉ số AQI theo 30. 60 và 90 ngày
for days in [30, 60, 90]:
    future_days = predict_future(model, df1, time_step, days)
    plt.figure(figsize=(20, 5))
    plt.plot(range(1, days + 1), future_days, label=f'Predicted AQI for {days} days', linestyle='--')
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.legend()
    plt.show()

# %% [markdown]
# TRAIN:TEST = 9:1

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
ytest1 = scaler.inverse_transform(ytest.reshape(-1,1))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 12s 216ms/step - loss: 0.0021
# Epoch 2/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0016
# Epoch 3/100
# 32/32 [==============================] - 5s 168ms/step - loss: 0.0015
# Epoch 4/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.0015
# Epoch 5/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0015
# Epoch 6/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0014
# Epoch 7/100
# 32/32 [==============================] - 6s 170ms/step - loss: 0.0014
# Epoch 8/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0014
# Epoch 9/100
# 32/32 [==============================] - 7s 209ms/step - loss: 0.0013
# Epoch 10/100
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0013
# Epoch 11/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0013
# Epoch 12/100
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0013
# Epoch 13/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0013
# Epoch 14/100
# 32/32 [==============================] - 5s 172ms/step - loss: 0.0013
# Epoch 15/100
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0012
# Epoch 16/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0012
# Epoch 17/100
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0012
# Epoch 18/100
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0012
# Epoch 19/100
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0012
# Epoch 20/100
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0012
# Epoch 21/100
# 32/32 [==============================] - 5s 147ms/step - loss: 0.0012
# Epoch 22/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0012
# Epoch 23/100
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0012
# Epoch 24/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0012
# Epoch 25/100
# 32/32 [==============================] - 6s 176ms/step - loss: 0.0012
# Epoch 26/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0012
# Epoch 27/100
# 32/32 [==============================] - 5s 147ms/step - loss: 0.0012
# Epoch 28/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0012
# Epoch 29/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0012
# Epoch 30/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0012
# Epoch 31/100
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0012
# Epoch 32/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0012
# Epoch 33/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011
# Epoch 34/100
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0011
# Epoch 35/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 36/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0011
# Epoch 37/100
# 32/32 [==============================] - 6s 178ms/step - loss: 0.0011
# Epoch 38/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0011
# Epoch 39/100
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0011
# Epoch 40/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0011
# Epoch 41/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0011
# Epoch 42/100
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0011
# Epoch 43/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0011
# Epoch 44/100
# 32/32 [==============================] - 5s 159ms/step - loss: 0.0011
# Epoch 45/100
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0011
# Epoch 46/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0012
# Epoch 47/100
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0011
# Epoch 48/100
# 32/32 [==============================] - 6s 174ms/step - loss: 0.0011
# Epoch 49/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 50/100
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0011
# Epoch 51/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0011
# Epoch 52/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 53/100
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0011
# Epoch 54/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 55/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011
# Epoch 56/100
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0011
# Epoch 57/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 58/100
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0011
# Epoch 59/100
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0011
# Epoch 60/100
# 32/32 [==============================] - 5s 147ms/step - loss: 0.0011
# Epoch 61/100
# 32/32 [==============================] - 6s 204ms/step - loss: 0.0011
# Epoch 62/100
# 32/32 [==============================] - 5s 152ms/step - loss: 0.0011
# Epoch 63/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 64/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0011
# Epoch 65/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 66/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011
# Epoch 67/100
# 32/32 [==============================] - 7s 203ms/step - loss: 0.0011
# Epoch 68/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 69/100
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0011
# Epoch 70/100
# 32/32 [==============================] - 6s 172ms/step - loss: 0.0011
# Epoch 71/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 72/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0011
# Epoch 73/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 74/100
# 32/32 [==============================] - 5s 147ms/step - loss: 0.0011
# Epoch 75/100
# 32/32 [==============================] - 7s 216ms/step - loss: 0.0011
# Epoch 76/100
# 32/32 [==============================] - 5s 147ms/step - loss: 0.0011
# Epoch 77/100
# 32/32 [==============================] - 5s 160ms/step - loss: 0.0011
# Epoch 78/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0011
# Epoch 79/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 80/100
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0011
# Epoch 81/100
# 32/32 [==============================] - 6s 172ms/step - loss: 0.0011
# Epoch 82/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 83/100
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0011
# Epoch 84/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0011
# Epoch 85/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0011
# Epoch 86/100
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0011
# Epoch 87/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0011
# Epoch 88/100
# 32/32 [==============================] - 6s 174ms/step - loss: 0.0011
# Epoch 89/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.0011
# Epoch 90/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0011
# Epoch 91/100
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0011
# Epoch 92/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0011
# Epoch 93/100
# 32/32 [==============================] - 5s 152ms/step - loss: 0.0011
# Epoch 94/100
# 32/32 [==============================] - 7s 217ms/step - loss: 0.0011
# Epoch 95/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0011
# Epoch 96/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0011
# Epoch 97/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0011
# Epoch 98/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.0011
# Epoch 99/100
# 32/32 [==============================] - 6s 204ms/step - loss: 0.0011
# Epoch 100/100
# 32/32 [==============================] - 6s 172ms/step - loss: 0.0011
# 63/63 [==============================] - 3s 35ms/step
# 5/5 [==============================] - 0s 35ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest1 , test_predict))
mae = mean_absolute_error(ytest1 , test_predict)
mape = mean_absolute_percentage_error(ytest1 , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 14.0546210298218
# MAE: 10.534666929672014
# MAPE: 0.22644990673403959

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(20, 5))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %%
# Dự đoán chỉ số AQI theo 30. 60 và 90 ngày
for days in [30, 60, 90]:
    future_days = predict_future(model, df1, time_step, days)
    plt.figure(figsize=(20, 5))
    plt.plot(range(1, days + 1), future_days, label=f'Predicted AQI for {days} days', linestyle='--')
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.legend()
    plt.show()
