# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# TRAIN:TEST = 7:3

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 13s 233ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0017 - val_loss: 9.7135e-04
# Epoch 3/100
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0017 - val_loss: 9.7557e-04
# Epoch 4/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 5/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0016 - val_loss: 9.5443e-04
# Epoch 6/100
# 25/25 [==============================] - 6s 247ms/step - loss: 0.0016 - val_loss: 9.8309e-04
# Epoch 7/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 8/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 9/100
# 25/25 [==============================] - 6s 242ms/step - loss: 0.0015 - val_loss: 9.2950e-04
# Epoch 10/100
# 25/25 [==============================] - 4s 169ms/step - loss: 0.0014 - val_loss: 9.0903e-04
# Epoch 11/100
# 25/25 [==============================] - 4s 169ms/step - loss: 0.0014 - val_loss: 9.2057e-04
# Epoch 12/100
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0014 - val_loss: 9.4712e-04
# Epoch 14/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0014 - val_loss: 8.8088e-04
# Epoch 15/100
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0014 - val_loss: 8.6092e-04
# Epoch 16/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0014 - val_loss: 8.4300e-04
# Epoch 17/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0014 - val_loss: 8.4888e-04
# Epoch 18/100
# 25/25 [==============================] - 6s 254ms/step - loss: 0.0013 - val_loss: 9.4894e-04
# Epoch 19/100
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0014 - val_loss: 8.3781e-04
# Epoch 20/100
# 25/25 [==============================] - 5s 192ms/step - loss: 0.0013 - val_loss: 8.0899e-04
# Epoch 21/100
# 25/25 [==============================] - 5s 218ms/step - loss: 0.0013 - val_loss: 8.3783e-04
# Epoch 22/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0014 - val_loss: 8.8581e-04
# Epoch 23/100
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0013 - val_loss: 8.1074e-04
# Epoch 24/100
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0013 - val_loss: 7.9034e-04
# Epoch 25/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0013 - val_loss: 8.8452e-04
# Epoch 26/100
# 25/25 [==============================] - 6s 232ms/step - loss: 0.0013 - val_loss: 7.9141e-04
# Epoch 27/100
# 25/25 [==============================] - 5s 186ms/step - loss: 0.0013 - val_loss: 8.0062e-04
# Epoch 28/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0013 - val_loss: 7.8072e-04
# Epoch 29/100
# 25/25 [==============================] - 6s 229ms/step - loss: 0.0012 - val_loss: 7.6703e-04
# Epoch 30/100
# 25/25 [==============================] - 5s 180ms/step - loss: 0.0013 - val_loss: 7.6963e-04
# Epoch 31/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0013 - val_loss: 7.7920e-04
# Epoch 32/100
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0012 - val_loss: 7.8284e-04
# Epoch 33/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0013 - val_loss: 8.4065e-04
# Epoch 34/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0013 - val_loss: 7.8517e-04
# Epoch 35/100
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0013 - val_loss: 7.8286e-04
# Epoch 36/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0013 - val_loss: 7.9267e-04
# Epoch 37/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0012 - val_loss: 8.0305e-04
# Epoch 38/100
# 25/25 [==============================] - 6s 245ms/step - loss: 0.0012 - val_loss: 7.7986e-04
# Epoch 39/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 8.1189e-04
# Epoch 40/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 7.6051e-04
# Epoch 41/100
# 25/25 [==============================] - 6s 256ms/step - loss: 0.0012 - val_loss: 7.6221e-04
# Epoch 42/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 8.0180e-04
# Epoch 43/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0012 - val_loss: 8.1343e-04
# Epoch 44/100
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0012 - val_loss: 7.6006e-04
# Epoch 45/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0012 - val_loss: 7.7779e-04
# Epoch 46/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0012 - val_loss: 8.0053e-04
# Epoch 47/100
# 25/25 [==============================] - 6s 248ms/step - loss: 0.0012 - val_loss: 7.7053e-04
# Epoch 48/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 7.7675e-04
# Epoch 49/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0012 - val_loss: 8.1119e-04
# Epoch 50/100
# 25/25 [==============================] - 6s 254ms/step - loss: 0.0012 - val_loss: 7.8943e-04
# Epoch 51/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.6923e-04
# Epoch 52/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.6347e-04
# Epoch 53/100
# 25/25 [==============================] - 6s 249ms/step - loss: 0.0012 - val_loss: 7.7157e-04
# Epoch 54/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0012 - val_loss: 7.7026e-04
# Epoch 55/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0012 - val_loss: 7.7255e-04
# Epoch 56/100
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0012 - val_loss: 8.6251e-04
# Epoch 57/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 8.0557e-04
# Epoch 58/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.7170e-04
# Epoch 59/100
# 25/25 [==============================] - 6s 243ms/step - loss: 0.0012 - val_loss: 7.8335e-04
# Epoch 60/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0012 - val_loss: 7.8212e-04
# Epoch 61/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.6901e-04
# Epoch 62/100
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0012 - val_loss: 7.6868e-04
# Epoch 63/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 7.8391e-04
# Epoch 64/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 7.7799e-04
# Epoch 65/100
# 25/25 [==============================] - 6s 241ms/step - loss: 0.0012 - val_loss: 7.7764e-04
# Epoch 66/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 7.9693e-04
# Epoch 67/100
# 25/25 [==============================] - 4s 181ms/step - loss: 0.0012 - val_loss: 7.7258e-04
# Epoch 68/100
# 25/25 [==============================] - 6s 240ms/step - loss: 0.0012 - val_loss: 7.8854e-04
# Epoch 69/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 8.4103e-04
# Epoch 70/100
# 25/25 [==============================] - 5s 182ms/step - loss: 0.0012 - val_loss: 7.8573e-04
# Epoch 71/100
# 25/25 [==============================] - 6s 237ms/step - loss: 0.0012 - val_loss: 7.8860e-04
# Epoch 72/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.6671e-04
# Epoch 73/100
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0012 - val_loss: 7.8322e-04
# Epoch 74/100
# 25/25 [==============================] - 7s 269ms/step - loss: 0.0012 - val_loss: 8.1971e-04
# Epoch 75/100
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0012 - val_loss: 7.7031e-04
# Epoch 76/100
# 25/25 [==============================] - 6s 253ms/step - loss: 0.0011 - val_loss: 7.7705e-04
# Epoch 77/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 7.7232e-04
# Epoch 78/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0012 - val_loss: 7.6686e-04
# Epoch 79/100
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0012 - val_loss: 7.6561e-04
# Epoch 80/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0011 - val_loss: 7.7817e-04
# Epoch 81/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0012 - val_loss: 7.6976e-04
# Epoch 82/100
# 25/25 [==============================] - 6s 245ms/step - loss: 0.0012 - val_loss: 7.7510e-04
# Epoch 83/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0011 - val_loss: 7.7176e-04
# Epoch 84/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 8.0111e-04
# Epoch 85/100
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0012 - val_loss: 7.7656e-04
# Epoch 86/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 8.0883e-04
# Epoch 87/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0012 - val_loss: 8.1820e-04
# Epoch 88/100
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0012 - val_loss: 7.7412e-04
# Epoch 89/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0011 - val_loss: 7.7771e-04
# Epoch 90/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0011 - val_loss: 8.2539e-04
# Epoch 91/100
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0012 - val_loss: 7.9068e-04
# Epoch 92/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 8.1213e-04
# Epoch 93/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 8.0291e-04
# Epoch 94/100
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0012 - val_loss: 7.7739e-04
# Epoch 95/100
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0011 - val_loss: 8.0130e-04
# Epoch 96/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0012 - val_loss: 7.7286e-04
# Epoch 97/100
# 25/25 [==============================] - 6s 254ms/step - loss: 0.0011 - val_loss: 7.6833e-04
# Epoch 98/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0011 - val_loss: 8.4733e-04
# Epoch 99/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0012 - val_loss: 7.9570e-04
# Epoch 100/100
# 25/25 [==============================] - 6s 254ms/step - loss: 0.0012 - val_loss: 8.6139e-04
# 49/49 [==============================] - 3s 35ms/step
# 19/19 [==============================] - 1s 36ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest , test_predict))
mae = mean_absolute_error(ytest , test_predict)
mape = mean_absolute_percentage_error(ytest , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 61.85969965749507
# MAE: 57.79140042557086
# MAPE: 2301.7136086226715

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %% [markdown]
# TRAIN:TEST = 8:2

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]

# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 12s 202ms/step - loss: 0.0021 - val_loss: 5.8384e-04
# Epoch 2/100
# 28/28 [==============================] - 6s 229ms/step - loss: 0.0017 - val_loss: 5.8145e-04
# Epoch 3/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0016 - val_loss: 5.6062e-04
# Epoch 4/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0015 - val_loss: 5.7200e-04
# Epoch 5/100
# 28/28 [==============================] - 6s 227ms/step - loss: 0.0015 - val_loss: 5.5382e-04
# Epoch 6/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0015 - val_loss: 5.6855e-04
# Epoch 7/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0015 - val_loss: 5.3084e-04
# Epoch 8/100
# 28/28 [==============================] - 6s 228ms/step - loss: 0.0014 - val_loss: 5.3035e-04
# Epoch 9/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0014 - val_loss: 5.2134e-04
# Epoch 10/100
# 28/28 [==============================] - 5s 162ms/step - loss: 0.0014 - val_loss: 5.8824e-04
# Epoch 11/100
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0014 - val_loss: 5.1892e-04
# Epoch 12/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0014 - val_loss: 6.0265e-04
# Epoch 13/100
# 28/28 [==============================] - 5s 174ms/step - loss: 0.0013 - val_loss: 4.9196e-04
# Epoch 14/100
# 28/28 [==============================] - 6s 213ms/step - loss: 0.0013 - val_loss: 4.9143e-04
# Epoch 15/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0013 - val_loss: 5.0876e-04
# Epoch 16/100
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0013 - val_loss: 5.3737e-04
# Epoch 17/100
# 28/28 [==============================] - 6s 200ms/step - loss: 0.0013 - val_loss: 5.3772e-04
# Epoch 18/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0013 - val_loss: 4.5175e-04
# Epoch 19/100
# 28/28 [==============================] - 5s 190ms/step - loss: 0.0013 - val_loss: 4.3902e-04
# Epoch 20/100
# 28/28 [==============================] - 5s 194ms/step - loss: 0.0013 - val_loss: 4.4194e-04
# Epoch 21/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0013 - val_loss: 4.3896e-04
# Epoch 22/100
# 28/28 [==============================] - 6s 203ms/step - loss: 0.0013 - val_loss: 4.2199e-04
# Epoch 23/100
# 28/28 [==============================] - 7s 244ms/step - loss: 0.0013 - val_loss: 4.8397e-04
# Epoch 24/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0013 - val_loss: 4.9795e-04
# Epoch 25/100
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0013 - val_loss: 4.3334e-04
# Epoch 26/100
# 28/28 [==============================] - 5s 172ms/step - loss: 0.0013 - val_loss: 4.0255e-04
# Epoch 27/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0013 - val_loss: 3.9878e-04
# Epoch 28/100
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0012 - val_loss: 5.4967e-04
# Epoch 29/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0013 - val_loss: 4.0384e-04
# Epoch 30/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0013 - val_loss: 4.0223e-04
# Epoch 31/100
# 28/28 [==============================] - 6s 230ms/step - loss: 0.0013 - val_loss: 4.3138e-04
# Epoch 32/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 4.2219e-04
# Epoch 33/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0013 - val_loss: 4.6208e-04
# Epoch 34/100
# 28/28 [==============================] - 6s 229ms/step - loss: 0.0012 - val_loss: 4.1773e-04
# Epoch 35/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 3.8708e-04
# Epoch 36/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 3.8754e-04
# Epoch 37/100
# 28/28 [==============================] - 6s 226ms/step - loss: 0.0012 - val_loss: 3.8310e-04
# Epoch 38/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.8425e-04
# Epoch 39/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 4.0925e-04
# Epoch 40/100
# 28/28 [==============================] - 6s 229ms/step - loss: 0.0012 - val_loss: 3.8161e-04
# Epoch 41/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.7966e-04
# Epoch 42/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 3.8302e-04
# Epoch 43/100
# 28/28 [==============================] - 6s 226ms/step - loss: 0.0013 - val_loss: 3.8476e-04
# Epoch 44/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 3.8603e-04
# Epoch 45/100
# 28/28 [==============================] - 5s 164ms/step - loss: 0.0012 - val_loss: 3.8948e-04
# Epoch 46/100
# 28/28 [==============================] - 6s 216ms/step - loss: 0.0012 - val_loss: 4.7251e-04
# Epoch 47/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.7921e-04
# Epoch 48/100
# 28/28 [==============================] - 5s 173ms/step - loss: 0.0012 - val_loss: 3.7928e-04
# Epoch 49/100
# 28/28 [==============================] - 6s 208ms/step - loss: 0.0012 - val_loss: 3.7885e-04
# Epoch 50/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.7723e-04
# Epoch 51/100
# 28/28 [==============================] - 5s 190ms/step - loss: 0.0012 - val_loss: 3.9116e-04
# Epoch 52/100
# 28/28 [==============================] - 5s 192ms/step - loss: 0.0012 - val_loss: 3.7615e-04
# Epoch 53/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 4.1677e-04
# Epoch 54/100
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0012 - val_loss: 3.7963e-04
# Epoch 55/100
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0012 - val_loss: 4.0033e-04
# Epoch 56/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0012 - val_loss: 3.8588e-04
# Epoch 57/100
# 28/28 [==============================] - 6s 215ms/step - loss: 0.0012 - val_loss: 5.2822e-04
# Epoch 58/100
# 28/28 [==============================] - 5s 159ms/step - loss: 0.0012 - val_loss: 3.7910e-04
# Epoch 59/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.8637e-04
# Epoch 60/100
# 28/28 [==============================] - 6s 225ms/step - loss: 0.0012 - val_loss: 3.9081e-04
# Epoch 61/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.7412e-04
# Epoch 62/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.9193e-04
# Epoch 63/100
# 28/28 [==============================] - 6s 227ms/step - loss: 0.0012 - val_loss: 3.9617e-04
# Epoch 64/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 4.0466e-04
# Epoch 65/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.8022e-04
# Epoch 66/100
# 28/28 [==============================] - 6s 229ms/step - loss: 0.0012 - val_loss: 3.7383e-04
# Epoch 67/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.7323e-04
# Epoch 68/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.7592e-04
# Epoch 69/100
# 28/28 [==============================] - 6s 226ms/step - loss: 0.0012 - val_loss: 3.9744e-04
# Epoch 70/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.9441e-04
# Epoch 71/100
# 28/28 [==============================] - 5s 165ms/step - loss: 0.0012 - val_loss: 3.7669e-04
# Epoch 72/100
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0012 - val_loss: 3.8593e-04
# Epoch 73/100
# 28/28 [==============================] - 4s 161ms/step - loss: 0.0012 - val_loss: 3.7982e-04
# Epoch 74/100
# 28/28 [==============================] - 5s 185ms/step - loss: 0.0012 - val_loss: 4.5682e-04
# Epoch 75/100
# 28/28 [==============================] - 8s 278ms/step - loss: 0.0012 - val_loss: 3.8778e-04
# Epoch 76/100
# 28/28 [==============================] - 4s 160ms/step - loss: 0.0012 - val_loss: 3.7934e-04
# Epoch 77/100
# 28/28 [==============================] - 5s 188ms/step - loss: 0.0011 - val_loss: 3.7849e-04
# Epoch 78/100
# 28/28 [==============================] - 6s 203ms/step - loss: 0.0012 - val_loss: 4.3854e-04
# Epoch 79/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.7984e-04
# Epoch 80/100
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0012 - val_loss: 3.7755e-04
# Epoch 81/100
# 28/28 [==============================] - 5s 176ms/step - loss: 0.0012 - val_loss: 4.0556e-04
# Epoch 82/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.9406e-04
# Epoch 83/100
# 28/28 [==============================] - 6s 225ms/step - loss: 0.0012 - val_loss: 3.9426e-04
# Epoch 84/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.8282e-04
# Epoch 85/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 4.0694e-04
# Epoch 86/100
# 28/28 [==============================] - 6s 233ms/step - loss: 0.0012 - val_loss: 3.7264e-04
# Epoch 87/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0012 - val_loss: 3.9185e-04
# Epoch 88/100
# 28/28 [==============================] - 5s 161ms/step - loss: 0.0012 - val_loss: 3.7756e-04
# Epoch 89/100
# 28/28 [==============================] - 6s 229ms/step - loss: 0.0012 - val_loss: 3.8277e-04
# Epoch 90/100
# 28/28 [==============================] - 4s 161ms/step - loss: 0.0012 - val_loss: 3.7542e-04
# Epoch 91/100
# 28/28 [==============================] - 5s 172ms/step - loss: 0.0011 - val_loss: 4.3725e-04
# Epoch 92/100
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0012 - val_loss: 3.8435e-04
# Epoch 93/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0011 - val_loss: 3.8572e-04
# Epoch 94/100
# 28/28 [==============================] - 5s 185ms/step - loss: 0.0012 - val_loss: 3.7911e-04
# Epoch 95/100
# 28/28 [==============================] - 6s 202ms/step - loss: 0.0012 - val_loss: 3.7532e-04
# Epoch 96/100
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0011 - val_loss: 3.7213e-04
# Epoch 97/100
# 28/28 [==============================] - 5s 194ms/step - loss: 0.0011 - val_loss: 3.7584e-04
# Epoch 98/100
# 28/28 [==============================] - 5s 187ms/step - loss: 0.0011 - val_loss: 4.0702e-04
# Epoch 99/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0012 - val_loss: 3.7036e-04
# Epoch 100/100
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0011 - val_loss: 4.0186e-04
# 56/56 [==============================] - 5s 55ms/step
# 12/12 [==============================] - 0s 34ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest , test_predict))
mae = mean_absolute_error(ytest , test_predict)
mape = mean_absolute_percentage_error(ytest , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 57.87641389221507
# MAE: 54.23716537711059
# MAPE: 1677.6005269932673

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')

# %% [markdown]
# TRAIN:TEST = 9:1

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# 2. Đọc file csv và gắng index với giá AQI
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/VietTri.csv')
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df = df[df['date'] <= '2024-06-01']
df1=df.reset_index()['AQI']

# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))
train_data = df1[:train_size]
test_data = df1[train_size:]
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)


#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)

# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 14s 212ms/step - loss: 0.0020 - val_loss: 6.5697e-04
# Epoch 2/100
# 32/32 [==============================] - 5s 166ms/step - loss: 0.0016 - val_loss: 4.3011e-04
# Epoch 3/100
# 32/32 [==============================] - 7s 203ms/step - loss: 0.0016 - val_loss: 4.1512e-04
# Epoch 4/100
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0015 - val_loss: 4.1739e-04
# Epoch 5/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0014 - val_loss: 4.3726e-04
# Epoch 6/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0014 - val_loss: 4.4594e-04
# Epoch 7/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0014 - val_loss: 3.8399e-04
# Epoch 8/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0014 - val_loss: 4.3609e-04
# Epoch 9/100
# 32/32 [==============================] - 5s 162ms/step - loss: 0.0013 - val_loss: 3.7283e-04
# Epoch 10/100
# 32/32 [==============================] - 7s 217ms/step - loss: 0.0013 - val_loss: 4.3056e-04
# Epoch 11/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0013 - val_loss: 3.5197e-04
# Epoch 12/100
# 32/32 [==============================] - 6s 173ms/step - loss: 0.0013 - val_loss: 3.3462e-04
# Epoch 13/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0013 - val_loss: 3.2676e-04
# Epoch 14/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0013 - val_loss: 5.0731e-04
# Epoch 15/100
# 32/32 [==============================] - 7s 218ms/step - loss: 0.0012 - val_loss: 3.2540e-04
# Epoch 16/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0012 - val_loss: 3.7006e-04
# Epoch 17/100
# 32/32 [==============================] - 5s 167ms/step - loss: 0.0012 - val_loss: 3.0260e-04
# Epoch 18/100
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0012 - val_loss: 2.9632e-04
# Epoch 19/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0012 - val_loss: 2.9926e-04
# Epoch 20/100
# 32/32 [==============================] - 7s 217ms/step - loss: 0.0012 - val_loss: 3.1346e-04
# Epoch 21/100
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0012 - val_loss: 3.5690e-04
# Epoch 22/100
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0012 - val_loss: 2.9767e-04
# Epoch 23/100
# 32/32 [==============================] - 7s 213ms/step - loss: 0.0012 - val_loss: 2.9529e-04
# Epoch 24/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0012 - val_loss: 3.2248e-04
# Epoch 25/100
# 32/32 [==============================] - 7s 206ms/step - loss: 0.0012 - val_loss: 2.9005e-04
# Epoch 26/100
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0012 - val_loss: 3.3295e-04
# Epoch 27/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0012 - val_loss: 2.8739e-04
# Epoch 28/100
# 32/32 [==============================] - 7s 218ms/step - loss: 0.0012 - val_loss: 3.3463e-04
# Epoch 29/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0012 - val_loss: 2.9233e-04
# Epoch 30/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0012 - val_loss: 2.9582e-04
# Epoch 31/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0012 - val_loss: 3.2339e-04
# Epoch 32/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.8447e-04
# Epoch 33/100
# 32/32 [==============================] - 7s 216ms/step - loss: 0.0012 - val_loss: 3.3228e-04
# Epoch 34/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 3.5787e-04
# Epoch 35/100
# 32/32 [==============================] - 6s 195ms/step - loss: 0.0012 - val_loss: 3.0109e-04
# Epoch 36/100
# 32/32 [==============================] - 6s 175ms/step - loss: 0.0011 - val_loss: 2.8810e-04
# Epoch 37/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 2.8734e-04
# Epoch 38/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0011 - val_loss: 3.2764e-04
# Epoch 39/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 3.1801e-04
# Epoch 40/100
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0011 - val_loss: 2.9358e-04
# Epoch 41/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0011 - val_loss: 2.8833e-04
# Epoch 42/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0011 - val_loss: 2.9443e-04
# Epoch 43/100
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0011 - val_loss: 3.5844e-04
# Epoch 44/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.9094e-04
# Epoch 45/100
# 32/32 [==============================] - 6s 174ms/step - loss: 0.0011 - val_loss: 3.4815e-04
# Epoch 46/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0011 - val_loss: 2.9294e-04
# Epoch 47/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 3.9057e-04
# Epoch 48/100
# 32/32 [==============================] - 7s 217ms/step - loss: 0.0011 - val_loss: 3.1453e-04
# Epoch 49/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.8600e-04
# Epoch 50/100
# 32/32 [==============================] - 5s 163ms/step - loss: 0.0011 - val_loss: 2.8840e-04
# Epoch 51/100
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0011 - val_loss: 3.0111e-04
# Epoch 52/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 3.1408e-04
# Epoch 53/100
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0011 - val_loss: 2.8907e-04
# Epoch 54/100
# 32/32 [==============================] - 6s 178ms/step - loss: 0.0011 - val_loss: 2.9530e-04
# Epoch 55/100
# 32/32 [==============================] - 7s 224ms/step - loss: 0.0011 - val_loss: 3.0030e-04
# Epoch 56/100
# 32/32 [==============================] - 6s 180ms/step - loss: 0.0011 - val_loss: 3.5520e-04
# Epoch 57/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.8708e-04
# Epoch 58/100
# 32/32 [==============================] - 7s 218ms/step - loss: 0.0011 - val_loss: 2.8673e-04
# Epoch 59/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 3.0085e-04
# Epoch 60/100
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0011 - val_loss: 3.1428e-04
# Epoch 61/100
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0011 - val_loss: 2.8761e-04
# Epoch 62/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0011 - val_loss: 2.8943e-04
# Epoch 63/100
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0011 - val_loss: 2.9082e-04
# Epoch 64/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 3.0019e-04
# Epoch 65/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0011 - val_loss: 2.8932e-04
# Epoch 66/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.0011 - val_loss: 3.0243e-04
# Epoch 67/100
# 32/32 [==============================] - 5s 159ms/step - loss: 0.0011 - val_loss: 2.9015e-04
# Epoch 68/100
# 32/32 [==============================] - 7s 221ms/step - loss: 0.0011 - val_loss: 2.9420e-04
# Epoch 69/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 2.9757e-04
# Epoch 70/100
# 32/32 [==============================] - 5s 171ms/step - loss: 0.0011 - val_loss: 2.8700e-04
# Epoch 71/100
# 32/32 [==============================] - 7s 202ms/step - loss: 0.0011 - val_loss: 3.2368e-04
# Epoch 72/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.8987e-04
# Epoch 73/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0011 - val_loss: 3.1297e-04
# Epoch 74/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.9090e-04
# Epoch 75/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 3.0018e-04
# Epoch 76/100
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0011 - val_loss: 3.4435e-04
# Epoch 77/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 3.4187e-04
# Epoch 78/100
# 32/32 [==============================] - 6s 205ms/step - loss: 0.0011 - val_loss: 2.8526e-04
# Epoch 79/100
# 32/32 [==============================] - 5s 164ms/step - loss: 0.0011 - val_loss: 3.4719e-04
# Epoch 80/100
# 32/32 [==============================] - 5s 159ms/step - loss: 0.0011 - val_loss: 2.8737e-04
# Epoch 81/100
# 32/32 [==============================] - 7s 220ms/step - loss: 0.0011 - val_loss: 2.9076e-04
# Epoch 82/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 3.0987e-04
# Epoch 83/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0011 - val_loss: 2.8847e-04
# Epoch 84/100
# 32/32 [==============================] - 6s 173ms/step - loss: 0.0011 - val_loss: 2.8947e-04
# Epoch 85/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0011 - val_loss: 2.8851e-04
# Epoch 86/100
# 32/32 [==============================] - 7s 220ms/step - loss: 0.0011 - val_loss: 2.9883e-04
# Epoch 87/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 2.9130e-04
# Epoch 88/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0011 - val_loss: 2.9836e-04
# Epoch 89/100
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0011 - val_loss: 2.8842e-04
# Epoch 90/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 3.0225e-04
# Epoch 91/100
# 32/32 [==============================] - 7s 221ms/step - loss: 0.0011 - val_loss: 2.9108e-04
# Epoch 92/100
# 32/32 [==============================] - 5s 157ms/step - loss: 0.0011 - val_loss: 2.9508e-04
# Epoch 93/100
# 32/32 [==============================] - 6s 178ms/step - loss: 0.0011 - val_loss: 2.9232e-04
# Epoch 94/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0011 - val_loss: 3.0507e-04
# Epoch 95/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 2.9210e-04
# Epoch 96/100
# 32/32 [==============================] - 7s 220ms/step - loss: 0.0011 - val_loss: 3.3016e-04
# Epoch 97/100
# 32/32 [==============================] - 5s 158ms/step - loss: 0.0011 - val_loss: 2.9062e-04
# Epoch 98/100
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0011 - val_loss: 2.9417e-04
# Epoch 99/100
# 32/32 [==============================] - 9s 269ms/step - loss: 0.0011 - val_loss: 3.0873e-04
# Epoch 100/100
# 32/32 [==============================] - 5s 159ms/step - loss: 0.0011 - val_loss: 3.7181e-04
# 63/63 [==============================] - 3s 36ms/step
# 5/5 [==============================] - 0s 33ms/step

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest , test_predict))
mae = mean_absolute_error(ytest , test_predict)
mape = mean_absolute_percentage_error(ytest , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 59.77631586269477
# MAE: 58.28155293200029
# MAPE: 1632.0568702538244

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# 14. Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# 15. Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# 16. Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')
