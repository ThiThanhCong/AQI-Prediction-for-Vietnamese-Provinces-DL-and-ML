# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Import thư viện cần thiết
from google.colab import drive
#drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('/content/drive/MyDrive/LSTM/Data/QuangNinh.csv')
df1=df.reset_index()['AQI']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 9s 459ms/step - loss: 0.0018 - val_loss: 0.0068
# Epoch 2/100
# 9/9 [==============================] - 2s 185ms/step - loss: 0.0012 - val_loss: 0.0069
# Epoch 3/100
# 9/9 [==============================] - 1s 158ms/step - loss: 0.0011 - val_loss: 0.0068
# Epoch 4/100
# 9/9 [==============================] - 1s 156ms/step - loss: 0.0011 - val_loss: 0.0068
# Epoch 5/100
# 9/9 [==============================] - 1s 156ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 6/100
# 9/9 [==============================] - 1s 157ms/step - loss: 0.0010 - val_loss: 0.0066
# Epoch 7/100
# 9/9 [==============================] - 1s 157ms/step - loss: 0.0010 - val_loss: 0.0065
# Epoch 8/100
# 9/9 [==============================] - 1s 157ms/step - loss: 9.9903e-04 - val_loss: 0.0064
# Epoch 9/100
# 9/9 [==============================] - 2s 205ms/step - loss: 0.0010 - val_loss: 0.0063
# Epoch 10/100
# 9/9 [==============================] - 2s 260ms/step - loss: 9.8597e-04 - val_loss: 0.0063
# Epoch 11/100
# 9/9 [==============================] - 2s 205ms/step - loss: 9.7710e-04 - val_loss: 0.0063
# Epoch 12/100
# 9/9 [==============================] - 1s 156ms/step - loss: 9.5773e-04 - val_loss: 0.0062
# Epoch 13/100
# 9/9 [==============================] - 1s 157ms/step - loss: 9.8966e-04 - val_loss: 0.0062
# Epoch 14/100
# 9/9 [==============================] - 1s 160ms/step - loss: 9.4150e-04 - val_loss: 0.0062
# Epoch 15/100
# 9/9 [==============================] - 1s 161ms/step - loss: 9.2025e-04 - val_loss: 0.0062
# Epoch 16/100
# 9/9 [==============================] - 1s 158ms/step - loss: 9.3012e-04 - val_loss: 0.0063
# Epoch 17/100
# 9/9 [==============================] - 1s 159ms/step - loss: 9.3555e-04 - val_loss: 0.0062
# Epoch 18/100
# 9/9 [==============================] - 2s 196ms/step - loss: 9.0969e-04 - val_loss: 0.0062
# Epoch 19/100
# 9/9 [==============================] - 2s 247ms/step - loss: 8.8236e-04 - val_loss: 0.0062
# Epoch 20/100
# 9/9 [==============================] - 2s 229ms/step - loss: 9.0774e-04 - val_loss: 0.0063
# Epoch 21/100
# 9/9 [==============================] - 1s 158ms/step - loss: 8.6761e-04 - val_loss: 0.0062
# Epoch 22/100
# 9/9 [==============================] - 1s 157ms/step - loss: 8.5669e-04 - val_loss: 0.0062
# Epoch 23/100
# 9/9 [==============================] - 1s 157ms/step - loss: 8.5113e-04 - val_loss: 0.0062
# Epoch 24/100
# 9/9 [==============================] - 1s 159ms/step - loss: 8.4795e-04 - val_loss: 0.0063
# Epoch 25/100
# 9/9 [==============================] - 1s 157ms/step - loss: 8.4003e-04 - val_loss: 0.0062
# Epoch 26/100
# 9/9 [==============================] - 1s 159ms/step - loss: 8.5173e-04 - val_loss: 0.0062
# Epoch 27/100
# 9/9 [==============================] - 1s 170ms/step - loss: 8.3602e-04 - val_loss: 0.0063
# Epoch 28/100
# 9/9 [==============================] - 2s 260ms/step - loss: 8.1242e-04 - val_loss: 0.0062
# Epoch 29/100
# 9/9 [==============================] - 2s 241ms/step - loss: 8.2140e-04 - val_loss: 0.0064
# Epoch 30/100
# 9/9 [==============================] - 1s 158ms/step - loss: 8.3933e-04 - val_loss: 0.0062
# Epoch 31/100
# 9/9 [==============================] - 1s 159ms/step - loss: 8.3958e-04 - val_loss: 0.0062
# Epoch 32/100
# 9/9 [==============================] - 1s 158ms/step - loss: 8.5113e-04 - val_loss: 0.0062
# Epoch 33/100
# 9/9 [==============================] - 1s 158ms/step - loss: 8.0764e-04 - val_loss: 0.0062
# Epoch 34/100
# 9/9 [==============================] - 1s 159ms/step - loss: 8.0204e-04 - val_loss: 0.0061
# Epoch 35/100
# 9/9 [==============================] - 1s 157ms/step - loss: 7.7521e-04 - val_loss: 0.0061
# Epoch 36/100
# 9/9 [==============================] - 1s 165ms/step - loss: 7.4208e-04 - val_loss: 0.0061
# Epoch 37/100
# 9/9 [==============================] - 2s 245ms/step - loss: 7.6548e-04 - val_loss: 0.0060
# Epoch 38/100
# 9/9 [==============================] - 3s 271ms/step - loss: 7.2008e-04 - val_loss: 0.0060
# Epoch 39/100
# 9/9 [==============================] - 1s 159ms/step - loss: 7.1711e-04 - val_loss: 0.0059
# Epoch 40/100
# 9/9 [==============================] - 1s 156ms/step - loss: 7.3311e-04 - val_loss: 0.0058
# Epoch 41/100
# 9/9 [==============================] - 2s 220ms/step - loss: 6.9995e-04 - val_loss: 0.0057
# Epoch 42/100
# 9/9 [==============================] - 1s 158ms/step - loss: 6.8562e-04 - val_loss: 0.0057
# Epoch 43/100
# 9/9 [==============================] - 1s 167ms/step - loss: 6.7690e-04 - val_loss: 0.0056
# Epoch 44/100
# 9/9 [==============================] - 1s 157ms/step - loss: 6.6144e-04 - val_loss: 0.0055
# Epoch 45/100
# 9/9 [==============================] - 2s 198ms/step - loss: 6.4776e-04 - val_loss: 0.0054
# Epoch 46/100
# 9/9 [==============================] - 2s 260ms/step - loss: 6.3615e-04 - val_loss: 0.0053
# Epoch 47/100
# 9/9 [==============================] - 2s 195ms/step - loss: 6.2344e-04 - val_loss: 0.0052
# Epoch 48/100
# 9/9 [==============================] - 1s 159ms/step - loss: 6.1276e-04 - val_loss: 0.0050
# Epoch 49/100
# 9/9 [==============================] - 1s 159ms/step - loss: 6.1313e-04 - val_loss: 0.0049
# Epoch 50/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.9461e-04 - val_loss: 0.0048
# Epoch 51/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.7744e-04 - val_loss: 0.0047
# Epoch 52/100
# 9/9 [==============================] - 1s 161ms/step - loss: 5.6893e-04 - val_loss: 0.0045
# Epoch 53/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.4885e-04 - val_loss: 0.0044
# Epoch 54/100
# 9/9 [==============================] - 2s 208ms/step - loss: 5.3600e-04 - val_loss: 0.0044
# Epoch 55/100
# 9/9 [==============================] - 2s 263ms/step - loss: 5.3057e-04 - val_loss: 0.0043
# Epoch 56/100
# 9/9 [==============================] - 2s 190ms/step - loss: 5.2396e-04 - val_loss: 0.0042
# Epoch 57/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.2781e-04 - val_loss: 0.0041
# Epoch 58/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.1383e-04 - val_loss: 0.0041
# Epoch 59/100
# 9/9 [==============================] - 1s 157ms/step - loss: 5.1251e-04 - val_loss: 0.0040
# Epoch 60/100
# 9/9 [==============================] - 1s 157ms/step - loss: 5.0827e-04 - val_loss: 0.0040
# Epoch 61/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.1534e-04 - val_loss: 0.0040
# Epoch 62/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.4836e-04 - val_loss: 0.0039
# Epoch 63/100
# 9/9 [==============================] - 2s 211ms/step - loss: 5.3075e-04 - val_loss: 0.0039
# Epoch 64/100
# 9/9 [==============================] - 2s 245ms/step - loss: 5.3801e-04 - val_loss: 0.0039
# Epoch 65/100
# 9/9 [==============================] - 2s 219ms/step - loss: 5.7198e-04 - val_loss: 0.0041
# Epoch 66/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.3312e-04 - val_loss: 0.0039
# Epoch 67/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.4324e-04 - val_loss: 0.0039
# Epoch 68/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.0950e-04 - val_loss: 0.0039
# Epoch 69/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.1927e-04 - val_loss: 0.0039
# Epoch 70/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.0679e-04 - val_loss: 0.0039
# Epoch 71/100
# 9/9 [==============================] - 1s 161ms/step - loss: 5.0413e-04 - val_loss: 0.0039
# Epoch 72/100
# 9/9 [==============================] - 2s 187ms/step - loss: 5.0996e-04 - val_loss: 0.0039
# Epoch 73/100
# 9/9 [==============================] - 2s 245ms/step - loss: 5.1150e-04 - val_loss: 0.0039
# Epoch 74/100
# 9/9 [==============================] - 2s 237ms/step - loss: 5.0698e-04 - val_loss: 0.0039
# Epoch 75/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.0420e-04 - val_loss: 0.0039
# Epoch 76/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.0537e-04 - val_loss: 0.0039
# Epoch 77/100
# 9/9 [==============================] - 1s 157ms/step - loss: 5.0621e-04 - val_loss: 0.0039
# Epoch 78/100
# 9/9 [==============================] - 1s 161ms/step - loss: 5.0377e-04 - val_loss: 0.0039
# Epoch 79/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.0466e-04 - val_loss: 0.0039
# Epoch 80/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.1875e-04 - val_loss: 0.0039
# Epoch 81/100
# 9/9 [==============================] - 2s 169ms/step - loss: 5.1036e-04 - val_loss: 0.0039
# Epoch 82/100
# 9/9 [==============================] - 2s 248ms/step - loss: 5.1250e-04 - val_loss: 0.0039
# Epoch 83/100
# 9/9 [==============================] - 2s 264ms/step - loss: 5.0524e-04 - val_loss: 0.0039
# Epoch 84/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.1868e-04 - val_loss: 0.0039
# Epoch 85/100
# 9/9 [==============================] - 1s 157ms/step - loss: 5.1916e-04 - val_loss: 0.0040
# Epoch 86/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.1984e-04 - val_loss: 0.0039
# Epoch 87/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.0313e-04 - val_loss: 0.0039
# Epoch 88/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.0753e-04 - val_loss: 0.0039
# Epoch 89/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.1087e-04 - val_loss: 0.0040
# Epoch 90/100
# 9/9 [==============================] - 1s 161ms/step - loss: 5.0874e-04 - val_loss: 0.0039
# Epoch 91/100
# 9/9 [==============================] - 2s 249ms/step - loss: 5.2008e-04 - val_loss: 0.0039
# Epoch 92/100
# 9/9 [==============================] - 4s 501ms/step - loss: 5.0424e-04 - val_loss: 0.0039
# Epoch 93/100
# 9/9 [==============================] - 2s 254ms/step - loss: 5.1148e-04 - val_loss: 0.0039
# Epoch 94/100
# 9/9 [==============================] - 2s 207ms/step - loss: 5.0778e-04 - val_loss: 0.0040
# Epoch 95/100
# 9/9 [==============================] - 1s 159ms/step - loss: 5.1925e-04 - val_loss: 0.0039
# Epoch 96/100
# 9/9 [==============================] - 1s 160ms/step - loss: 5.1199e-04 - val_loss: 0.0040
# Epoch 97/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.1563e-04 - val_loss: 0.0040
# Epoch 98/100
# 9/9 [==============================] - 1s 158ms/step - loss: 5.0401e-04 - val_loss: 0.0039
# Epoch 99/100
# 9/9 [==============================] - 2s 209ms/step - loss: 5.0899e-04 - val_loss: 0.0039
# Epoch 100/100
# 9/9 [==============================] - 2s 249ms/step - loss: 5.1184e-04 - val_loss: 0.0039

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 18/18 [==============================] - 2s 31ms/step
# 6/6 [==============================] - 0s 31ms/step

# %%
# 11. Chuẩn hóa dữ liệu test_predict
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE,MAE,MAPE
rmse = np.sqrt(mean_squared_error(ytest , test_predict))
mae = mean_absolute_error(ytest , test_predict)
mape = mean_absolute_percentage_error(ytest , test_predict)

print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
# Out:
# RMSE: 45.362529152807795
# MAE: 30.376536583375504
# MAPE: 992.0384159509767

# %%
# 13. Tạo hàm dự đoán
def predict_future(model, data, time_step, future_days):
    temp_input = data[-time_step:].reshape(1, -1)
    temp_input = list(temp_input[0])
    future_output = []

    for _ in range(future_days):
        if len(temp_input) > time_step:
            temp_input = temp_input[1:]
        input_data = np.array(temp_input).reshape(1, time_step, 1)
        prediction = model.predict(input_data, verbose=0)
        temp_input.append(prediction[0][0])
        future_output.append(prediction[0][0])

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output

# %%
# Dự đoán 30, 60, 90 ngày
future_30_days = predict_future(model, df1, time_step, 30)
future_60_days = predict_future(model, df1, time_step, 60)
future_90_days = predict_future(model, df1, time_step, 90)

# %%
# Hàm trực quan dữ liệu
def create_plot(future_days, future_data, future_label):
    plt.figure(figsize=(16, 9))

    # Plot train data
    plt.plot(scaler.inverse_transform(train_data), label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(train_data), len(train_data) + len(test_data)), scaler.inverse_transform(test_data), label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(train_data) + time_step, len(train_data) + time_step + len(test_predict)), test_predict, label='Test Predict')

    # Plot future predictions
    plt.plot(np.arange(len(df1), len(df1) + future_days), future_data, label=future_label)

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - {future_label}')
    plt.legend()
    plt.show()

# Create plots
create_plot(30, future_30_days, '30 Days Prediction')
create_plot(60, future_60_days, '60 Days Prediction')
create_plot(90, future_90_days, '90 Days Prediction')
