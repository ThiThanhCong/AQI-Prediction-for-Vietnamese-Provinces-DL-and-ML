# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Conv1D, Add, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv(r'C:\Users\ASUS\Documents\Zalo Received Files\HaNoi.csv')
print(df.columns)

# Preprocess the data
df['date'] = pd.to_datetime(df['date'], dayfirst=True)  # Chuyển đổi cột date thành định dạng thời gian
df.set_index('date', inplace=True)  # Đặt cột date làm index


# Check for null values and drop them
null_count = df.isnull().sum()
print(null_count)
df = df.dropna()

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['AQI']])

# Prepare data function
def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

timesteps = 30  # Độ dài của cửa sổ trượt
X, y = prepare_data(scaled_data, timesteps)
# Out:
# Index(['Index', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'AQI'], dtype='object')
# Index    0
# pm25     0
# pm10     0
# o3       0
# no2      0
# so2      0
# co       0
# AQI      0
# dtype: int64

# %%
# Build the model
input_layer = Input(shape=(timesteps, 1))
# x = LSTM(64, return_sequences=True)(input_layer)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(input_layer)
x = Conv1D(64, kernel_size=2, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=1, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(1, kernel_size=3, padding='same')(x)
x = Add()([x, input_layer])
output_layer = Activation('tanh')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 30, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 30, 64)            │             256 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 30, 64)            │           8,256 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 30, 64)            │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 30, 64)            │           4,160 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 30, 64)            │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 30, 64)            │          12,352 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 30, 64)            │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 30, 1)             │             193 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 30, 1)             │               0 │ conv1d_4[0][0],            │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 30, 1)             │               0 │ add[0][0]                  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 25,985 (101.50 KB)
#  Trainable params: 25,601 (100.00 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
def predict_future(model, data, time_step, future_days, scaler):
    temp_input = data[-time_step:].reshape(1, time_step, 1)
    future_output = []

    for _ in range(future_days):
        prediction = model.predict(temp_input, verbose=0)
        future_output.append(prediction[0][0])
        temp_input = np.roll(temp_input, -1)  # Dịch chuyển các phần tử sang trái 1 vị trí
        temp_input[-1][-1] = prediction[0][0]  # Gán giá trị dự đoán vào vị trí cuối cùng của temp_input

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output


def custom_round(number):
    if number >= 0:
        return int(number + 0.5)  # Làm tròn lên
    else:
        return int(number - 0.5)  # Làm tròn xuống
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_sizes = [0.7, 0.8, 0.9]
for train_size_ratio in train_sizes:
    # Split data into training and testing sets
    train_size = int(len(X) * train_size_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    # Reshape data to match model input
    X_train = np.reshape(X_train, (X_train.shape[0], timesteps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], timesteps, 1))
    print(y_train)
    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Inverse transform the predictions and true values
    y_pred_inverse = scaler.inverse_transform(y_pred[:, -1, 0].reshape(-1, 1))
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_train_inverse = scaler.inverse_transform(y_train.reshape(-1, 1))
    
      # Calculate error metrics
    rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    mape = mean_absolute_percentage_error(y_test_inverse, y_pred_inverse)
    
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'Mean Absolute Percentage Error (MAPE): {mape}%')  
       # Calculate future predictions
    df1 = df.reset_index()['AQI']
    scaler = MinMaxScaler(feature_range=(0, 1))
    df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))
    future_30_days = predict_future(model, df1, timesteps, 30, scaler)
    future_60_days = predict_future(model, df1, timesteps, 60, scaler)
    future_90_days = predict_future(model, df1, timesteps, 90, scaler)
    # Plot the results
    plt.figure(figsize=(10, 9))

    # Plot train data
    plt.plot(y_train_inverse, label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inverse, label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(y_train) + timesteps, len(y_train) + timesteps + len(y_pred_inverse)), y_pred_inverse, label='Test Predict')
    plt.plot(np.arange(len(X), len(X) + 30), future_30_days, label="30 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 60), future_60_days, label="60 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 90), future_90_days, label="90 Days Prediction")

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - split {custom_round(train_size_ratio * 10)}:{custom_round((1-train_size_ratio) * 10)}')
    plt.legend()
    plt.show()
# Out:
# [[0.31622177]
#  [0.1889117 ]
#  [0.20123203]
#  ...
#  [0.03696099]
#  [0.0349076 ]
#  [0.02874743]]
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1573 - mae: 0.2956 - val_loss: 0.0146 - val_mae: 0.0972
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184 - mae: 0.1025 - val_loss: 0.0169 - val_mae: 0.1041
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - mae: 0.0870 - val_loss: 0.0166 - val_mae: 0.1023
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0102 - mae: 0.0764 - val_loss: 0.0123 - val_mae: 0.0849
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - mae: 0.0717 - val_loss: 0.0138 - val_mae: 0.0916
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mae: 0.0697 - val_loss: 0.0116 - val_mae: 0.0823
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - mae: 0.0662 - val_loss: 0.0097 - val_mae: 0.0704
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - mae: 0.0662 - val_loss: 0.0099 - val_mae: 0.0722
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - mae: 0.0635 - val_loss: 0.0124 - val_mae: 0.0864
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - mae: 0.0645 - val_loss: 0.0076 - val_mae: 0.0684
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0624 - val_loss: 0.0106 - val_mae: 0.0801
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - mae: 0.0674 - val_loss: 0.0068 - val_mae: 0.0610
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - mae: 0.0608 - val_loss: 0.0068 - val_mae: 0.0636
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mae: 0.0656 - val_loss: 0.0089 - val_mae: 0.0719
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mae: 0.0600 - val_loss: 0.0072 - val_mae: 0.0650
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mae: 0.0609 - val_loss: 0.0067 - val_mae: 0.0618
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mae: 0.0594 - val_loss: 0.0069 - val_mae: 0.0607
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - mae: 0.0606 - val_loss: 0.0068 - val_mae: 0.0602
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0592 - val_loss: 0.0065 - val_mae: 0.0626
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0586 - val_loss: 0.0065 - val_mae: 0.0608
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - mae: 0.0588 - val_loss: 0.0067 - val_mae: 0.0665
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - mae: 0.0588 - val_loss: 0.0074 - val_mae: 0.0657
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mae: 0.0590 - val_loss: 0.0082 - val_mae: 0.0679
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - mae: 0.0593 - val_loss: 0.0065 - val_mae: 0.0610
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0582 - val_loss: 0.0070 - val_mae: 0.0647
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0566 - val_loss: 0.0060 - val_mae: 0.0614
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - mae: 0.0585 - val_loss: 0.0078 - val_mae: 0.0660
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - mae: 0.0586 - val_loss: 0.0063 - val_mae: 0.0583
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - mae: 0.0569 - val_loss: 0.0074 - val_mae: 0.0641
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - mae: 0.0578 - val_loss: 0.0061 - val_mae: 0.0572
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0570 - val_loss: 0.0071 - val_mae: 0.0709
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0543 - val_loss: 0.0060 - val_mae: 0.0582
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0568 - val_loss: 0.0085 - val_mae: 0.0725
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0550 - val_loss: 0.0067 - val_mae: 0.0633
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - mae: 0.0611 - val_loss: 0.0059 - val_mae: 0.0578
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0581 - val_loss: 0.0062 - val_mae: 0.0577
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - mae: 0.0560 - val_loss: 0.0060 - val_mae: 0.0589
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - mae: 0.0578 - val_loss: 0.0060 - val_mae: 0.0563
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0558 - val_loss: 0.0072 - val_mae: 0.0649
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0577 - val_loss: 0.0074 - val_mae: 0.0660
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mae: 0.0575 - val_loss: 0.0057 - val_mae: 0.0565
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - mae: 0.0575 - val_loss: 0.0056 - val_mae: 0.0556
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0533 - val_loss: 0.0066 - val_mae: 0.0609
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0567 - val_loss: 0.0061 - val_mae: 0.0614
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mae: 0.0570 - val_loss: 0.0060 - val_mae: 0.0570
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0568 - val_loss: 0.0058 - val_mae: 0.0581
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0562 - val_loss: 0.0059 - val_mae: 0.0577
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0553 - val_loss: 0.0084 - val_mae: 0.0701
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0064 - val_mae: 0.0599
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0546 - val_loss: 0.0057 - val_mae: 0.0563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Root Mean Squared Error (RMSE): 28.739766368460504
# Mean Absolute Error (MAE): 20.54329884899736
# Mean Absolute Percentage Error (MAPE): 31.412595299060115%
# [[0.31622177]
#  [0.1889117 ]
#  [0.20123203]
#  ...
#  [0.04517454]
#  [0.0862423 ]
#  [0.0349076 ]]
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0539 - val_loss: 0.0072 - val_mae: 0.0625
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - mae: 0.0569 - val_loss: 0.0065 - val_mae: 0.0625
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0566 - val_loss: 0.0065 - val_mae: 0.0648
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - mae: 0.0569 - val_loss: 0.0077 - val_mae: 0.0632
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0557 - val_loss: 0.0082 - val_mae: 0.0666
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0555 - val_loss: 0.0068 - val_mae: 0.0638
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0551 - val_loss: 0.0072 - val_mae: 0.0614
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0552 - val_loss: 0.0062 - val_mae: 0.0575
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0533 - val_loss: 0.0060 - val_mae: 0.0608
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0562 - val_loss: 0.0060 - val_mae: 0.0604
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0543 - val_loss: 0.0063 - val_mae: 0.0594
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0566 - val_loss: 0.0069 - val_mae: 0.0637
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0538 - val_loss: 0.0065 - val_mae: 0.0658
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0538 - val_loss: 0.0069 - val_mae: 0.0654
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - mae: 0.0550 - val_loss: 0.0058 - val_mae: 0.0574
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0548 - val_loss: 0.0055 - val_mae: 0.0562
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0535 - val_loss: 0.0066 - val_mae: 0.0605
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mae: 0.0549 - val_loss: 0.0062 - val_mae: 0.0608
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mae: 0.0558 - val_loss: 0.0055 - val_mae: 0.0565
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0527 - val_loss: 0.0070 - val_mae: 0.0622
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0570 - val_loss: 0.0091 - val_mae: 0.0708
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0567 - val_loss: 0.0064 - val_mae: 0.0605
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0545 - val_loss: 0.0065 - val_mae: 0.0619
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0518 - val_loss: 0.0067 - val_mae: 0.0611
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0541 - val_loss: 0.0061 - val_mae: 0.0618
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0533 - val_loss: 0.0058 - val_mae: 0.0614
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0530 - val_loss: 0.0089 - val_mae: 0.0721
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0539 - val_loss: 0.0061 - val_mae: 0.0581
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0527 - val_loss: 0.0093 - val_mae: 0.0708
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0559 - val_loss: 0.0065 - val_mae: 0.0623
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0529 - val_loss: 0.0062 - val_mae: 0.0608
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0568 - val_loss: 0.0076 - val_mae: 0.0667
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0532 - val_loss: 0.0063 - val_mae: 0.0598
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0530 - val_loss: 0.0066 - val_mae: 0.0604
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0537 - val_loss: 0.0079 - val_mae: 0.0682
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - mae: 0.0595 - val_loss: 0.0061 - val_mae: 0.0597
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0533 - val_loss: 0.0064 - val_mae: 0.0617
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0536 - val_loss: 0.0060 - val_mae: 0.0586
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - mae: 0.0528 - val_loss: 0.0064 - val_mae: 0.0636
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0541 - val_loss: 0.0060 - val_mae: 0.0615
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0532 - val_loss: 0.0056 - val_mae: 0.0554
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0540 - val_loss: 0.0069 - val_mae: 0.0622
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mae: 0.0524 - val_loss: 0.0062 - val_mae: 0.0590
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0537 - val_loss: 0.0061 - val_mae: 0.0640
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0512 - val_loss: 0.0057 - val_mae: 0.0588
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0546 - val_loss: 0.0053 - val_mae: 0.0564
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0537 - val_loss: 0.0058 - val_mae: 0.0571
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0554 - val_loss: 0.0055 - val_mae: 0.0569
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0542 - val_loss: 0.0061 - val_mae: 0.0573
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0516 - val_loss: 0.0066 - val_mae: 0.0645
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 32.03840175086036
# Mean Absolute Error (MAE): 24.295845968443302
# Mean Absolute Percentage Error (MAPE): 30.35099545887175%
# [[0.31622177]
#  [0.1889117 ]
#  [0.20123203]
#  ...
#  [0.18685832]
#  [0.1211499 ]
#  [0.19096509]]
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0581 - val_loss: 0.0040 - val_mae: 0.0483
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0544 - val_loss: 0.0048 - val_mae: 0.0516
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0556 - val_loss: 0.0067 - val_mae: 0.0644
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0542 - val_loss: 0.0049 - val_mae: 0.0525
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mae: 0.0566 - val_loss: 0.0050 - val_mae: 0.0574
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mae: 0.0572 - val_loss: 0.0044 - val_mae: 0.0545
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0553 - val_loss: 0.0047 - val_mae: 0.0568
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0541 - val_loss: 0.0036 - val_mae: 0.0474
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0509 - val_loss: 0.0043 - val_mae: 0.0540
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - mae: 0.0553 - val_loss: 0.0044 - val_mae: 0.0507
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0563 - val_loss: 0.0040 - val_mae: 0.0513
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - mae: 0.0568 - val_loss: 0.0037 - val_mae: 0.0477
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0548 - val_loss: 0.0037 - val_mae: 0.0468
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0556 - val_loss: 0.0050 - val_mae: 0.0541
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - mae: 0.0626 - val_loss: 0.0063 - val_mae: 0.0664
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0581 - val_loss: 0.0055 - val_mae: 0.0623
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - mae: 0.0591 - val_loss: 0.0042 - val_mae: 0.0519
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0569 - val_loss: 0.0045 - val_mae: 0.0527
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0568 - val_loss: 0.0037 - val_mae: 0.0486
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0554 - val_loss: 0.0077 - val_mae: 0.0675
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - mae: 0.0619 - val_loss: 0.0041 - val_mae: 0.0493
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0563 - val_loss: 0.0046 - val_mae: 0.0533
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0570 - val_loss: 0.0038 - val_mae: 0.0482
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0040 - val_mae: 0.0492
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0568 - val_loss: 0.0035 - val_mae: 0.0452
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0037 - val_mae: 0.0458
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - mae: 0.0590 - val_loss: 0.0041 - val_mae: 0.0507
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0540 - val_loss: 0.0036 - val_mae: 0.0467
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0571 - val_loss: 0.0048 - val_mae: 0.0553
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - mae: 0.0554 - val_loss: 0.0038 - val_mae: 0.0480
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0543 - val_loss: 0.0043 - val_mae: 0.0539
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0549 - val_loss: 0.0038 - val_mae: 0.0468
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - mae: 0.0570 - val_loss: 0.0038 - val_mae: 0.0478
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0554 - val_loss: 0.0041 - val_mae: 0.0519
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mae: 0.0538 - val_loss: 0.0036 - val_mae: 0.0460
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0560 - val_loss: 0.0039 - val_mae: 0.0500
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0539 - val_loss: 0.0040 - val_mae: 0.0509
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0566 - val_loss: 0.0038 - val_mae: 0.0464
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0548 - val_loss: 0.0041 - val_mae: 0.0477
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0570 - val_loss: 0.0044 - val_mae: 0.0527
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - mae: 0.0562 - val_loss: 0.0036 - val_mae: 0.0458
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0546 - val_loss: 0.0041 - val_mae: 0.0514
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0519 - val_loss: 0.0039 - val_mae: 0.0499
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0567 - val_loss: 0.0037 - val_mae: 0.0486
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0555 - val_loss: 0.0035 - val_mae: 0.0463
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - mae: 0.0585 - val_loss: 0.0042 - val_mae: 0.0522
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0577 - val_loss: 0.0040 - val_mae: 0.0518
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - mae: 0.0560 - val_loss: 0.0040 - val_mae: 0.0481
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0529 - val_loss: 0.0045 - val_mae: 0.0549
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - mae: 0.0580 - val_loss: 0.0038 - val_mae: 0.0494
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 28.7184884121038
# Mean Absolute Error (MAE): 21.505664547143034
# Mean Absolute Percentage Error (MAPE): 26.15921926587229%
