# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Conv1D, Add, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv(r'C:\Users\ASUS\Documents\Zalo Received Files\VietTri.csv')
print(df.columns)

# Preprocess the data
df['date'] = pd.to_datetime(df['date'])  # Chuyển đổi cột date thành định dạng thời gian
df.set_index('date', inplace=True)  # Đặt cột date làm index


# Check for null values and drop them
null_count = df.isnull().sum()
print(null_count)
df = df.dropna()

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['AQI']])

# Prepare data function
def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

timesteps = 30  # Độ dài của cửa sổ trượt
X, y = prepare_data(scaled_data, timesteps)
# Out:
# Index(['Index', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'AQI'], dtype='object')
# Index    0
# pm25     0
# pm10     0
# o3       0
# no2      0
# so2      0
# co       0
# AQI      0
# dtype: int64

# %%
# Build the model
input_layer = Input(shape=(timesteps, 1))
# x = LSTM(64, return_sequences=True)(input_layer)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(input_layer)
x = Conv1D(64, kernel_size=2, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=1, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(1, kernel_size=3, padding='same')(x)
x = Add()([x, input_layer])
output_layer = Activation('tanh')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 30, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 30, 64)            │             256 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 30, 64)            │           8,256 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 30, 64)            │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 30, 64)            │           4,160 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 30, 64)            │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 30, 64)            │          12,352 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 30, 64)            │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 30, 1)             │             193 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 30, 1)             │               0 │ conv1d_4[0][0],            │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 30, 1)             │               0 │ add[0][0]                  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 25,985 (101.50 KB)
#  Trainable params: 25,601 (100.00 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
def predict_future(model, data, time_step, future_days, scaler):
    temp_input = data[-time_step:].reshape(1, time_step, 1)
    future_output = []

    for _ in range(future_days):
        prediction = model.predict(temp_input, verbose=0)
        future_output.append(prediction[0][0])
        temp_input = np.roll(temp_input, -1)  # Dịch chuyển các phần tử sang trái 1 vị trí
        temp_input[-1][-1] = prediction[0][0]  # Gán giá trị dự đoán vào vị trí cuối cùng của temp_input

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output


def custom_round(number):
    if number >= 0:
        return int(number + 0.5)  # Làm tròn lên
    else:
        return int(number - 0.5)  # Làm tròn xuống
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_sizes = [0.7, 0.8, 0.9]
for train_size_ratio in train_sizes:
    # Split data into training and testing sets
    train_size = int(len(X) * train_size_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    # Reshape data to match model input
    X_train = np.reshape(X_train, (X_train.shape[0], timesteps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], timesteps, 1))
    print(y_train)
    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Inverse transform the predictions and true values
    y_pred_inverse = scaler.inverse_transform(y_pred[:, -1, 0].reshape(-1, 1))
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_train_inverse = scaler.inverse_transform(y_train.reshape(-1, 1))
    
    # Calculate error metrics
    rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    mape = mean_absolute_percentage_error(y_test_inverse, y_pred_inverse)
    
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'Mean Absolute Percentage Error (MAPE): {mape}%')  
       # Calculate future predictions
    df1 = df.reset_index()['AQI']
    scaler = MinMaxScaler(feature_range=(0, 1))
    df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))
    future_30_days = predict_future(model, df1, timesteps, 30, scaler)
    future_60_days = predict_future(model, df1, timesteps, 60, scaler)
    future_90_days = predict_future(model, df1, timesteps, 90, scaler)
    # Plot the results
    plt.figure(figsize=(10, 9))

    # Plot train data
    plt.plot(y_train_inverse, label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inverse, label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(y_train) + timesteps, len(y_train) + timesteps + len(y_pred_inverse)), y_pred_inverse, label='Test Predict')
    plt.plot(np.arange(len(X), len(X) + 30), future_30_days, label="30 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 60), future_60_days, label="60 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 90), future_90_days, label="90 Days Prediction")

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - split {custom_round(train_size_ratio * 10)}:{custom_round((1-train_size_ratio) * 10)}')
    plt.legend()
    plt.show()
# Out:
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.0098401 ]
#  [0.0098401 ]
#  [0.0098401 ]]
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1282 - mae: 0.2576 - val_loss: 0.0074 - val_mae: 0.0506
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - mae: 0.0805 - val_loss: 0.0158 - val_mae: 0.0671
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - mae: 0.0617 - val_loss: 0.0208 - val_mae: 0.0737
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - mae: 0.0520 - val_loss: 0.0238 - val_mae: 0.0874
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - mae: 0.0515 - val_loss: 0.0216 - val_mae: 0.0763
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0386 - val_loss: 0.0188 - val_mae: 0.0633
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0390 - val_loss: 0.0176 - val_mae: 0.0760
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0383 - val_loss: 0.0140 - val_mae: 0.0669
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0433 - val_loss: 0.0127 - val_mae: 0.0741
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0353 - val_loss: 0.0083 - val_mae: 0.0516
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0350 - val_loss: 0.0081 - val_mae: 0.0621
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0416 - val_loss: 0.0048 - val_mae: 0.0421
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0342 - val_loss: 0.0035 - val_mae: 0.0377
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0361 - val_loss: 0.0040 - val_mae: 0.0464
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0336 - val_loss: 0.0023 - val_mae: 0.0366
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0372 - val_loss: 0.0019 - val_mae: 0.0289
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0337 - val_loss: 0.0018 - val_mae: 0.0268
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0323 - val_loss: 0.0022 - val_mae: 0.0355
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0297 - val_loss: 0.0029 - val_mae: 0.0349
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mae: 0.0347 - val_loss: 0.0030 - val_mae: 0.0430
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0309 - val_loss: 0.0048 - val_mae: 0.0566
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0338 - val_loss: 0.0021 - val_mae: 0.0322
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0286 - val_loss: 0.0017 - val_mae: 0.0258
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0299 - val_loss: 0.0027 - val_mae: 0.0419
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0302 - val_loss: 0.0029 - val_mae: 0.0414
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0313 - val_loss: 0.0026 - val_mae: 0.0385
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0025 - val_mae: 0.0381
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0313 - val_loss: 0.0017 - val_mae: 0.0253
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0311 - val_loss: 0.0015 - val_mae: 0.0237
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0280 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0303 - val_loss: 0.0025 - val_mae: 0.0344
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0336 - val_loss: 0.0016 - val_mae: 0.0275
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0346 - val_loss: 0.0028 - val_mae: 0.0428
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0313 - val_loss: 0.0015 - val_mae: 0.0245
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 0.0025 - val_mae: 0.0365
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0036 - val_mae: 0.0514
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0334 - val_loss: 0.0015 - val_mae: 0.0246
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0283 - val_loss: 0.0018 - val_mae: 0.0277
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0335 - val_loss: 0.0022 - val_mae: 0.0366
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0320 - val_loss: 0.0019 - val_mae: 0.0353
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0326 - val_loss: 0.0013 - val_mae: 0.0230
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0281 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0017 - val_mae: 0.0262
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0276 - val_loss: 0.0015 - val_mae: 0.0243
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0298 - val_loss: 0.0014 - val_mae: 0.0229
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0285 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0314 - val_loss: 0.0016 - val_mae: 0.0309
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0316 - val_loss: 0.0014 - val_mae: 0.0254
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0323 - val_loss: 0.0012 - val_mae: 0.0224
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0304 - val_loss: 0.0014 - val_mae: 0.0270
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Root Mean Squared Error (RMSE): 24.544450594556718
# Mean Absolute Error (MAE): 16.320530614633668
# Mean Absolute Percentage Error (MAPE): 43.435022140468725%
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.01599016]
#  [0.01476015]
#  [0.02460025]]
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - mae: 0.0292 - val_loss: 0.0011 - val_mae: 0.0243
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mae: 0.0305 - val_loss: 9.8729e-04 - val_mae: 0.0236
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0269 - val_loss: 0.0018 - val_mae: 0.0353
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mae: 0.0312 - val_loss: 0.0033 - val_mae: 0.0491
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0289 - val_loss: 0.0011 - val_mae: 0.0228
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0300 - val_loss: 8.7825e-04 - val_mae: 0.0229
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0281 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0302 - val_loss: 0.0013 - val_mae: 0.0298
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0012 - val_mae: 0.0246
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0300 - val_loss: 0.0012 - val_mae: 0.0256
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0300 - val_loss: 0.0011 - val_mae: 0.0256
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0014 - val_mae: 0.0294
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0012 - val_mae: 0.0264
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0258 - val_loss: 9.6374e-04 - val_mae: 0.0226
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0293 - val_loss: 0.0015 - val_mae: 0.0328
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0326 - val_loss: 0.0010 - val_mae: 0.0242
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0304 - val_loss: 0.0015 - val_mae: 0.0321
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0284 - val_loss: 0.0012 - val_mae: 0.0290
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0285 - val_loss: 0.0044 - val_mae: 0.0539
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0023 - val_mae: 0.0372
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0309 - val_loss: 0.0014 - val_mae: 0.0265
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0279 - val_loss: 0.0019 - val_mae: 0.0365
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0305 - val_loss: 0.0012 - val_mae: 0.0268
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0267 - val_loss: 0.0012 - val_mae: 0.0276
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0023 - val_mae: 0.0413
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0306 - val_loss: 0.0018 - val_mae: 0.0341
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0258 - val_loss: 0.0012 - val_mae: 0.0253
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0285 - val_loss: 0.0013 - val_mae: 0.0266
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 0.0015 - val_mae: 0.0318
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0358 - val_loss: 9.9605e-04 - val_mae: 0.0252
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0298 - val_loss: 9.3937e-04 - val_mae: 0.0234
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0022 - val_mae: 0.0367
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0298 - val_loss: 8.8755e-04 - val_mae: 0.0233
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0302 - val_loss: 0.0010 - val_mae: 0.0246
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0281 - val_loss: 8.5838e-04 - val_mae: 0.0214
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0308 - val_loss: 8.8913e-04 - val_mae: 0.0227
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0291 - val_loss: 9.5054e-04 - val_mae: 0.0220
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0254 - val_loss: 0.0013 - val_mae: 0.0293
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0277 - val_loss: 0.0012 - val_mae: 0.0249
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0313 - val_loss: 0.0012 - val_mae: 0.0242
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0303 - val_loss: 9.2362e-04 - val_mae: 0.0249
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0329 - val_loss: 0.0029 - val_mae: 0.0433
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0027 - val_mae: 0.0433
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0317 - val_loss: 0.0019 - val_mae: 0.0359
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0289 - val_loss: 9.0964e-04 - val_mae: 0.0232
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0276 - val_loss: 0.0012 - val_mae: 0.0264
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0263 - val_loss: 0.0023 - val_mae: 0.0398
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0302 - val_loss: 0.0015 - val_mae: 0.0277
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0315 - val_loss: 0.0011 - val_mae: 0.0244
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 22.256388526618334
# Mean Absolute Error (MAE): 17.10278663141974
# Mean Absolute Percentage Error (MAPE): 37.29139002122983%
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.01599016]
#  [0.01599016]
#  [0.01599016]]
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0283 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0301 - val_loss: 4.7121e-04 - val_mae: 0.0157
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0325 - val_loss: 4.7096e-04 - val_mae: 0.0151
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0291 - val_loss: 4.3451e-04 - val_mae: 0.0171
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mae: 0.0273 - val_loss: 4.4133e-04 - val_mae: 0.0157
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mae: 0.0262 - val_loss: 6.6217e-04 - val_mae: 0.0195
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0323 - val_loss: 4.8855e-04 - val_mae: 0.0180
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0298 - val_loss: 0.0016 - val_mae: 0.0348
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0291 - val_loss: 9.6602e-04 - val_mae: 0.0246
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0286 - val_loss: 4.7418e-04 - val_mae: 0.0153
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0289 - val_loss: 6.7466e-04 - val_mae: 0.0201
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0275 - val_loss: 5.7376e-04 - val_mae: 0.0185
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0277 - val_loss: 6.6703e-04 - val_mae: 0.0217
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 5.1249e-04 - val_mae: 0.0160
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 4.9428e-04 - val_mae: 0.0166
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0274 - val_loss: 6.4464e-04 - val_mae: 0.0177
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0290 - val_loss: 0.0026 - val_mae: 0.0447
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mae: 0.0281 - val_loss: 5.3607e-04 - val_mae: 0.0175
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0277 - val_loss: 4.9718e-04 - val_mae: 0.0152
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0288 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mae: 0.0293 - val_loss: 9.3199e-04 - val_mae: 0.0237
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0285 - val_loss: 5.7539e-04 - val_mae: 0.0171
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0280 - val_loss: 6.1266e-04 - val_mae: 0.0215
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0308 - val_loss: 0.0021 - val_mae: 0.0393
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0322 - val_loss: 4.8616e-04 - val_mae: 0.0151
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0273 - val_loss: 8.0484e-04 - val_mae: 0.0236
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0318 - val_loss: 4.0157e-04 - val_mae: 0.0154
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0276 - val_loss: 7.1740e-04 - val_mae: 0.0207
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0275 - val_loss: 5.8399e-04 - val_mae: 0.0210
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mae: 0.0260 - val_loss: 0.0011 - val_mae: 0.0294
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0304 - val_loss: 0.0011 - val_mae: 0.0267
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0014 - val_mae: 0.0328
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0315 - val_loss: 3.7947e-04 - val_mae: 0.0150
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0306 - val_loss: 4.1908e-04 - val_mae: 0.0157
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0280 - val_loss: 7.5516e-04 - val_mae: 0.0237
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0276 - val_loss: 8.3266e-04 - val_mae: 0.0255
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0314 - val_loss: 5.3322e-04 - val_mae: 0.0187
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0277 - val_loss: 5.5352e-04 - val_mae: 0.0176
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0272 - val_loss: 0.0015 - val_mae: 0.0274
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0286 - val_loss: 6.7190e-04 - val_mae: 0.0219
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0281 - val_loss: 5.9376e-04 - val_mae: 0.0190
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0291 - val_loss: 0.0014 - val_mae: 0.0326
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0309 - val_loss: 3.8937e-04 - val_mae: 0.0145
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mae: 0.0253 - val_loss: 4.0496e-04 - val_mae: 0.0153
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0288 - val_loss: 6.8630e-04 - val_mae: 0.0212
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0293
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0301 - val_loss: 5.7946e-04 - val_mae: 0.0189
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0286 - val_loss: 4.4965e-04 - val_mae: 0.0165
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0251 - val_loss: 6.1442e-04 - val_mae: 0.0191
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 3.8801e-04 - val_mae: 0.0141
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Root Mean Squared Error (RMSE): 15.148456207730089
# Mean Absolute Error (MAE): 10.148636612398871
# Mean Absolute Percentage Error (MAPE): 22.72746161939755%
