# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Conv1D, Add, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv(r'C:\Users\ASUS\Documents\Zalo Received Files\VietTri.csv')
print(df.columns)

# Preprocess the data
df['date'] = pd.to_datetime(df['date'], dayfirst=True)  # Chuyển đổi cột date thành định dạng thời gian
df.set_index('date', inplace=True)  # Đặt cột date làm index


# Check for null values and drop them
null_count = df.isnull().sum()
print(null_count)
df = df.dropna()

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['AQI']])

# Prepare data function
def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(len(data) - timesteps):
        X.append(data[i:i + timesteps])
        y.append(data[i + timesteps])
    return np.array(X), np.array(y)

timesteps = 30  # Độ dài của cửa sổ trượt
X, y = prepare_data(scaled_data, timesteps)
# Out:
# Index(['Index', 'date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co', 'AQI'], dtype='object')
# Index    0
# pm25     0
# pm10     0
# o3       0
# no2      0
# so2      0
# co       0
# AQI      0
# dtype: int64

# %%
# Build the model
input_layer = Input(shape=(timesteps, 1))
x = LSTM(64, return_sequences=True)(input_layer)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = Conv1D(64, kernel_size=2, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=1, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Conv1D(1, kernel_size=3, padding='same')(x)
x = Add()([x, input_layer])
output_layer = Activation('tanh')(x)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 30, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ (None, 30, 64)            │          16,896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 30, 64)            │          12,352 │ lstm[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 30, 64)            │           8,256 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 30, 64)            │             256 │ conv1d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 30, 64)            │           4,160 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 30, 64)            │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 30, 64)            │          12,352 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 30, 64)            │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 30, 1)             │             193 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 30, 1)             │               0 │ conv1d_4[0][0],            │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 30, 1)             │               0 │ add[0][0]                  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 54,977 (214.75 KB)
#  Trainable params: 54,593 (213.25 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
def predict_future(model, data, time_step, future_days, scaler):
    temp_input = data[-time_step:].reshape(1, time_step, 1)
    future_output = []

    for _ in range(future_days):
        prediction = model.predict(temp_input, verbose=0)
        future_output.append(prediction[0][0])
        temp_input = np.roll(temp_input, -1)  # Dịch chuyển các phần tử sang trái 1 vị trí
        temp_input[-1][-1] = prediction[0][0]  # Gán giá trị dự đoán vào vị trí cuối cùng của temp_input

    future_output = scaler.inverse_transform(np.array(future_output).reshape(-1, 1))
    return future_output


def custom_round(number):
    if number >= 0:
        return int(number + 0.5)  # Làm tròn lên
    else:
        return int(number - 0.5)  # Làm tròn xuống

# %%
train_sizes = [0.7, 0.8, 0.9]
for train_size_ratio in train_sizes:
    # Split data into training and testing sets
    train_size = int(len(X) * train_size_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    # Reshape data to match model input
    X_train = np.reshape(X_train, (X_train.shape[0], timesteps, 1))
    X_test = np.reshape(X_test, (X_test.shape[0], timesteps, 1))
    print(y_train)
    # Train the model
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
    
    # Predict on test data
    y_pred = model.predict(X_test)
    
    # Inverse transform the predictions and true values
    y_pred_inverse = scaler.inverse_transform(y_pred[:, -1, 0].reshape(-1, 1))
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_train_inverse = scaler.inverse_transform(y_train.reshape(-1, 1))
    
    # Calculate error metrics
    rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')   
       # Calculate future predictions
    df1 = df.reset_index()['AQI']
    scaler = MinMaxScaler(feature_range=(0, 1))
    df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))
    future_30_days = predict_future(model, df1, timesteps, 30, scaler)
    future_60_days = predict_future(model, df1, timesteps, 60, scaler)
    future_90_days = predict_future(model, df1, timesteps, 90, scaler)
    # Plot the results
    plt.figure(figsize=(10, 9))

    # Plot train data
    plt.plot(y_train_inverse, label='Train Data')

    # Plot test data
    plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inverse, label='Test Data')

    # Plot test predictions
    plt.plot(np.arange(len(y_train) + timesteps, len(y_train) + timesteps + len(y_pred_inverse)), y_pred_inverse, label='Test Predict')
    plt.plot(np.arange(len(X), len(X) + 30), future_30_days, label="30 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 60), future_60_days, label="60 Days Prediction")
    plt.plot(np.arange(len(X), len(X) + 90), future_90_days, label="90 Days Prediction")

    # Add labels and legend
    plt.xlabel('Days')
    plt.ylabel('AQI')
    plt.title(f'AQI Predictions - split {custom_round(train_size_ratio * 10)}:{custom_round((1-train_size_ratio) * 10)}')
    plt.legend()
    plt.show()
# Out:
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.0098401 ]
#  [0.0098401 ]
#  [0.0098401 ]]
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1792 - mae: 0.3047 - val_loss: 0.0121 - val_mae: 0.1013
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0083 - mae: 0.0688 - val_loss: 0.0634 - val_mae: 0.2435
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - mae: 0.0565 - val_loss: 0.1099 - val_mae: 0.3230
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0044 - mae: 0.0497 - val_loss: 0.1331 - val_mae: 0.3571
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0048 - mae: 0.0465 - val_loss: 0.1351 - val_mae: 0.3615
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0040 - mae: 0.0421 - val_loss: 0.1107 - val_mae: 0.3283
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0044 - mae: 0.0440 - val_loss: 0.0702 - val_mae: 0.2599
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0425 - val_mae: 0.1963
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0346 - val_mae: 0.1757
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030 - mae: 0.0371 - val_loss: 0.0237 - val_mae: 0.1396
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0034 - mae: 0.0343 - val_loss: 0.0150 - val_mae: 0.1052
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - mae: 0.0387 - val_loss: 0.0146 - val_mae: 0.1040
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - mae: 0.0355 - val_loss: 0.0088 - val_mae: 0.0699
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - mae: 0.0335 - val_loss: 0.0065 - val_mae: 0.0672
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0321 - val_loss: 0.0058 - val_mae: 0.0607
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - mae: 0.0350 - val_loss: 0.0039 - val_mae: 0.0509
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0036 - mae: 0.0343 - val_loss: 0.0025 - val_mae: 0.0368
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0027 - val_mae: 0.0406
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - mae: 0.0334 - val_loss: 0.0036 - val_mae: 0.0469
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0033 - val_mae: 0.0442
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0028 - val_mae: 0.0411
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - mae: 0.0308 - val_loss: 0.0024 - val_mae: 0.0377
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - mae: 0.0324 - val_loss: 0.0028 - val_mae: 0.0409
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021 - mae: 0.0303 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0293 - val_loss: 0.0019 - val_mae: 0.0320
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0319 - val_loss: 0.0016 - val_mae: 0.0290
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025 - mae: 0.0320 - val_loss: 0.0024 - val_mae: 0.0348
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - mae: 0.0335 - val_loss: 0.0014 - val_mae: 0.0274
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0308 - val_loss: 0.0030 - val_mae: 0.0441
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - mae: 0.0333 - val_loss: 0.0014 - val_mae: 0.0253
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - mae: 0.0331 - val_loss: 0.0015 - val_mae: 0.0267
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - mae: 0.0297 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0030 - mae: 0.0323 - val_loss: 0.0027 - val_mae: 0.0385
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0293 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - mae: 0.0300 - val_loss: 0.0030 - val_mae: 0.0433
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0301 - val_loss: 0.0020 - val_mae: 0.0318
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - mae: 0.0306 - val_loss: 0.0026 - val_mae: 0.0410
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - mae: 0.0292 - val_loss: 0.0016 - val_mae: 0.0270
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - mae: 0.0337 - val_loss: 0.0016 - val_mae: 0.0288
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - mae: 0.0331 - val_loss: 0.0016 - val_mae: 0.0278
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0325 - val_loss: 0.0014 - val_mae: 0.0269
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - mae: 0.0302 - val_loss: 0.0013 - val_mae: 0.0253
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0032 - mae: 0.0335 - val_loss: 0.0019 - val_mae: 0.0316
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0026 - val_mae: 0.0375
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - mae: 0.0364 - val_loss: 0.0019 - val_mae: 0.0315
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0027 - val_mae: 0.0404
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - mae: 0.0342 - val_loss: 0.0017 - val_mae: 0.0290
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - mae: 0.0301 - val_loss: 0.0019 - val_mae: 0.0327
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - mae: 0.0322 - val_loss: 0.0015 - val_mae: 0.0276
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Root Mean Squared Error (RMSE): 31.085977431974708
# Mean Absolute Error (MAE): 25.69360095605083
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.01599016]
#  [0.01476015]
#  [0.02460025]]
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0254
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - mae: 0.0292 - val_loss: 0.0011 - val_mae: 0.0263
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0281 - val_loss: 0.0014 - val_mae: 0.0305
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - mae: 0.0332 - val_loss: 0.0019 - val_mae: 0.0347
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - mae: 0.0295 - val_loss: 0.0015 - val_mae: 0.0294
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0272 - val_loss: 0.0015 - val_mae: 0.0307
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0291 - val_loss: 0.0019 - val_mae: 0.0345
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - mae: 0.0314 - val_loss: 0.0010 - val_mae: 0.0239
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0019 - mae: 0.0281 - val_loss: 0.0015 - val_mae: 0.0288
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - mae: 0.0281 - val_loss: 0.0017 - val_mae: 0.0319
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0295 - val_loss: 0.0013 - val_mae: 0.0272
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - mae: 0.0290 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - mae: 0.0306 - val_loss: 0.0010 - val_mae: 0.0245
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0276 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0263 - val_loss: 0.0014 - val_mae: 0.0284
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - mae: 0.0315 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0292 - val_loss: 9.8840e-04 - val_mae: 0.0229
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0268 - val_loss: 0.0013 - val_mae: 0.0276
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - mae: 0.0303 - val_loss: 0.0012 - val_mae: 0.0277
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0282 - val_loss: 0.0011 - val_mae: 0.0242
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - mae: 0.0269 - val_loss: 0.0015 - val_mae: 0.0318
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - mae: 0.0279 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0269 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0013 - val_mae: 0.0301
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - mae: 0.0270 - val_loss: 0.0019 - val_mae: 0.0325
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - mae: 0.0297 - val_loss: 0.0031 - val_mae: 0.0480
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - mae: 0.0328 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - mae: 0.0286 - val_loss: 9.7319e-04 - val_mae: 0.0232
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0013 - val_mae: 0.0297
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0280 - val_loss: 9.1838e-04 - val_mae: 0.0232
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0016 - val_mae: 0.0315
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - mae: 0.0311 - val_loss: 0.0022 - val_mae: 0.0369
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - mae: 0.0302 - val_loss: 0.0011 - val_mae: 0.0266
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - mae: 0.0286 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0269 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018 - mae: 0.0268 - val_loss: 0.0011 - val_mae: 0.0257
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0272 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0285 - val_loss: 0.0011 - val_mae: 0.0236
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0272 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - mae: 0.0270 - val_loss: 9.4111e-04 - val_mae: 0.0229
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0284 - val_loss: 0.0013 - val_mae: 0.0260
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - mae: 0.0295 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021 - mae: 0.0281 - val_loss: 0.0011 - val_mae: 0.0261
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - mae: 0.0277 - val_loss: 0.0015 - val_mae: 0.0308
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - mae: 0.0291 - val_loss: 0.0016 - val_mae: 0.0321
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0273 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0012 - val_mae: 0.0257
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Root Mean Squared Error (RMSE): 18.95930286302526
# Mean Absolute Error (MAE): 14.718282551601016
# [[0.09471095]
#  [0.11808118]
#  [0.10701107]
#  ...
#  [0.01599016]
#  [0.01599016]
#  [0.01599016]]
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 8.2898e-04 - val_mae: 0.0233
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - mae: 0.0279 - val_loss: 9.0397e-04 - val_mae: 0.0225
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - mae: 0.0275 - val_loss: 7.8681e-04 - val_mae: 0.0210
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0274 - val_loss: 6.7159e-04 - val_mae: 0.0194
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0030 - mae: 0.0347 - val_loss: 8.5457e-04 - val_mae: 0.0229
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - mae: 0.0291 - val_loss: 8.8197e-04 - val_mae: 0.0236
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - mae: 0.0293 - val_loss: 0.0011 - val_mae: 0.0268
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0274 - val_loss: 8.8830e-04 - val_mae: 0.0232
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0020 - mae: 0.0277 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - mae: 0.0285 - val_loss: 7.1659e-04 - val_mae: 0.0208
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0016 - mae: 0.0276 - val_loss: 6.1531e-04 - val_mae: 0.0189
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - mae: 0.0299 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0032 - mae: 0.0334 - val_loss: 0.0012 - val_mae: 0.0286
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - mae: 0.0274 - val_loss: 7.2676e-04 - val_mae: 0.0214
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - mae: 0.0276 - val_loss: 7.4311e-04 - val_mae: 0.0223
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - mae: 0.0291 - val_loss: 8.3005e-04 - val_mae: 0.0221
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - mae: 0.0269 - val_loss: 0.0016 - val_mae: 0.0315
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0019 - mae: 0.0298 - val_loss: 0.0025 - val_mae: 0.0418
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0026 - mae: 0.0288 - val_loss: 9.0550e-04 - val_mae: 0.0235
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - mae: 0.0274 - val_loss: 7.2347e-04 - val_mae: 0.0229
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - mae: 0.0296 - val_loss: 5.9769e-04 - val_mae: 0.0183
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - mae: 0.0274 - val_loss: 9.9310e-04 - val_mae: 0.0258
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0277
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - mae: 0.0302 - val_loss: 0.0026 - val_mae: 0.0432
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0266 - val_loss: 8.9141e-04 - val_mae: 0.0241
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0022 - mae: 0.0284 - val_loss: 7.2722e-04 - val_mae: 0.0200
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0272 - val_loss: 6.0757e-04 - val_mae: 0.0205
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0019 - mae: 0.0289 - val_loss: 0.0014 - val_mae: 0.0323
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - mae: 0.0298 - val_loss: 5.0791e-04 - val_mae: 0.0164
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0266 - val_loss: 5.4286e-04 - val_mae: 0.0194
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0281 - val_loss: 6.5897e-04 - val_mae: 0.0198
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 0.0019 - val_mae: 0.0343
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 6.1213e-04 - val_mae: 0.0197
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - mae: 0.0279 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - mae: 0.0279 - val_loss: 7.6514e-04 - val_mae: 0.0211
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0275 - val_loss: 0.0024 - val_mae: 0.0409
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - mae: 0.0301 - val_loss: 5.8214e-04 - val_mae: 0.0200
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0264 - val_loss: 6.3508e-04 - val_mae: 0.0191
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0037 - mae: 0.0308 - val_loss: 8.8766e-04 - val_mae: 0.0238
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0014 - mae: 0.0265 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0014 - mae: 0.0270 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - mae: 0.0279 - val_loss: 9.6737e-04 - val_mae: 0.0261
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - mae: 0.0261 - val_loss: 5.9010e-04 - val_mae: 0.0189
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - mae: 0.0303 - val_loss: 9.7249e-04 - val_mae: 0.0245
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0035 - mae: 0.0297 - val_loss: 8.7257e-04 - val_mae: 0.0227
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - mae: 0.0276 - val_loss: 5.7257e-04 - val_mae: 0.0180
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - mae: 0.0277 - val_loss: 7.0405e-04 - val_mae: 0.0206
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 7.0441e-04 - val_mae: 0.0219
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - mae: 0.0282 - val_loss: 6.8866e-04 - val_mae: 0.0214
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Root Mean Squared Error (RMSE): 14.09488989588138
# Mean Absolute Error (MAE): 9.351617434929157
